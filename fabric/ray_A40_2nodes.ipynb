# %% [markdown]
# # Using FABRIC GPUs
#
# Your compute nodes can include GPUs. These devices are made available as FABRIC components and can be added to your nodes like any other component.
#
# This example notebook will demonstrate how to reserve and use Nvidia GPU devices on FABRIC.

# %% [markdown]
# ## Setup the Experiment
#
# #### Import FABRIC API

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import ipaddress

from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_16e17 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_16e17 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_16e17 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_16e17_row0_col0, #T_16e17_row0_col1, #T_16e17_row1_col0, #T_16e17_row1_col1, #T_16e17_row2_col0, #T_16e17_row2_col1, #T_16e17_row3_col0, #T_16e17_row3_col1, #T_16e17_row4_col0, #T_16e17_row4_col1, #T_16e17_row5_col0, #T_16e17_row5_col1, #T_16e17_row6_col0, #T_16e17_row6_col1, #T_16e17_row7_col0, #T_16e17_row7_col1, #T_16e17_row8_col0, #T_16e17_row8_col1, #T_16e17_row9_col0, #T_16e17_row9_col1, #T_16e17_row10_col0, #T_16e17_row10_col1, #T_16e17_row11_col0, #T_16e17_row11_col1, #T_16e17_row12_col0, #T_16e17_row12_col1, #T_16e17_row13_col0, #T_16e17_row13_col1, #T_16e17_row14_col0, #T_16e17_row14_col1, #T_16e17_row15_col0, #T_16e17_row15_col1, #T_16e17_row16_col0, #T_16e17_row16_col1, #T_16e17_row17_col0, #T_16e17_row17_col1, #T_16e17_row18_col0, #T_16e17_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_16e17">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_16e17_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_16e17_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_16e17_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_16e17_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_16e17_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_16e17_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_16e17_row5_col1" class="data row5 col1" >1eb0c915-27b6-4421-aab1-27ae42ded922</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_16e17_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_16e17_row7_col1" class="data row7 col1" >jbrassil_0034513446</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_16e17_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/id_fabric_bastion_traffic</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_16e17_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_16e17_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_16e17_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_16e17_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_16e17_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_16e17_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_16e17_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_16e17_row16_col1" class="data row16 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_16e17_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_16e17_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_16e17_row18_col1" class="data row18 col1" >ray</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create a Node
#
# The cells below help you create a slice that contains a single node with an attached GPU.
#
# ### Select GPU Type and select the FABRIC Site
#
# First decide on which GPU type you want to try - this will determine the subset of sites where your VM can be placed.

# %%
# pick which GPU type we will use (execute this cell). 

# choices include
# GPU_RTX6000
# GPU_TeslaT4
# GPU_A30
# GPU_A40
GPU_CHOICE = 'GPU_A40' 

# don't edit - convert from GPU type to a resource column name
# to use in filter lambda function below
choice_to_column = {
    "GPU_RTX6000": "rtx6000_available",
    "GPU_TeslaT4": "tesla_t4_available",
    "GPU_A30": "a30_available",
    "GPU_A40": "a40_available"
}

column_name = choice_to_column.get(GPU_CHOICE, "Unknown")
print(f'{column_name=}')
# Out:
# column_name='a40_available'

# %% [markdown]
# Give the slice and the node in it meaningful names.

# %%
# name the slice and the node 
slice_name=f'A40-CERN-perf1'
node1_name='gpu-node1'
node2_name='gpu-node2'

network_name='net1'

print(f'Will create slice "{slice_name}" with node "{node1_name}"')
# Out:
# Will create slice "A40-CERN-perf1" with node "gpu-node1"

# %% [markdown]
# Use a lambda filter to figure out which site the node will go to.

# %%
# find a site with at least one available GPU of the selected type
site_override = None

if site_override:
    site = site_override
else:
    site = fablib.get_random_site(filter_function=lambda x: x[column_name] > 0)
print(f'Preparing to create slice "{slice_name}" with node {node1_name} and node {node2_name}  in site {site}')
# Out:
# Preparing to create slice "A40-CERN-perf1" with node gpu-node1 and node gpu-node2  in site CERN

# %% [markdown]
# Create the desired slice with a GPU component.

# %%
# Create Slice. Note that by default submit() call will poll for 360 seconds every 10-20 seconds
# waiting for slice to come up. Normal expected time is around 2 minutes. 
slice = fablib.new_slice(name=slice_name)

# Network
net1 = slice.add_l2network(name=network_name, subnet=IPv4Network("192.168.100.0/24"))

# Add node with a 100G drive and a couple of CPU cores (default)
node1 = slice.add_node(name=node1_name, site=site, disk=100, image='default_ubuntu_24')
node1.add_component(model=GPU_CHOICE, name='gpu1')
iface1 = node1.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface1.set_mode('auto')
net1.add_interface(iface1)

node2 = slice.add_node(name=node2_name, site=site, disk=100, image='default_ubuntu_24')
node2.add_component(model=GPU_CHOICE, name='gpu2')

iface2 = node2.add_component(model='NIC_Basic', name='nic1').get_interfaces()[0]
iface2.set_mode('auto')
net1.add_interface(iface2)

#Submit Slice Request
slice.submit();
# Out:
# Retry: 14, Time: 333 sec
# <style type="text/css">
# #T_910e7 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_910e7 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_910e7 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_910e7_row0_col0, #T_910e7_row0_col1, #T_910e7_row1_col0, #T_910e7_row1_col1, #T_910e7_row2_col0, #T_910e7_row2_col1, #T_910e7_row3_col0, #T_910e7_row3_col1, #T_910e7_row4_col0, #T_910e7_row4_col1, #T_910e7_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_910e7_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_910e7">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_910e7_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_910e7_row0_col1" class="data row0 col1" >c02bacf6-d049-4522-8878-8446d8a6a33c</td>
#     </tr>
#     <tr>
#       <td id="T_910e7_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_910e7_row1_col1" class="data row1 col1" >A40-CERN-perf1</td>
#     </tr>
#     <tr>
#       <td id="T_910e7_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_910e7_row2_col1" class="data row2 col1" >2025-01-14 14:47:08 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_910e7_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_910e7_row3_col1" class="data row3 col1" >2025-01-13 14:47:08 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_910e7_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_910e7_row4_col1" class="data row4 col1" >1eb0c915-27b6-4421-aab1-27ae42ded922</td>
#     </tr>
#     <tr>
#       <td id="T_910e7_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_910e7_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b994d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b994d th {
#   text-align: left;
# }
# #T_b994d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b994d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b994d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b994d_row0_col0, #T_b994d_row0_col1, #T_b994d_row0_col2, #T_b994d_row0_col3, #T_b994d_row0_col4, #T_b994d_row0_col5, #T_b994d_row0_col6, #T_b994d_row0_col7, #T_b994d_row0_col8, #T_b994d_row0_col9, #T_b994d_row0_col10, #T_b994d_row0_col13, #T_b994d_row0_col14, #T_b994d_row0_col15, #T_b994d_row1_col0, #T_b994d_row1_col1, #T_b994d_row1_col2, #T_b994d_row1_col3, #T_b994d_row1_col4, #T_b994d_row1_col5, #T_b994d_row1_col6, #T_b994d_row1_col7, #T_b994d_row1_col8, #T_b994d_row1_col9, #T_b994d_row1_col10, #T_b994d_row1_col13, #T_b994d_row1_col14, #T_b994d_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_b994d_row0_col11, #T_b994d_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_b994d_row0_col12, #T_b994d_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_b994d">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_b994d_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b994d_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b994d_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_b994d_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_b994d_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_b994d_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_b994d_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_b994d_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_b994d_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_b994d_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_b994d_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_b994d_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_b994d_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_b994d_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_b994d_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_b994d_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b994d_row0_col0" class="data row0 col0" >7cb0d975-8926-499f-8742-afc4684e4525</td>
#       <td id="T_b994d_row0_col1" class="data row0 col1" >gpu-node1</td>
#       <td id="T_b994d_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_b994d_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_b994d_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_b994d_row0_col5" class="data row0 col5" >default_ubuntu_24</td>
#       <td id="T_b994d_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_b994d_row0_col7" class="data row0 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_b994d_row0_col8" class="data row0 col8" >CERN</td>
#       <td id="T_b994d_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_b994d_row0_col10" class="data row0 col10" >2001:400:a100:3090:f816:3eff:fe43:6d39</td>
#       <td id="T_b994d_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_b994d_row0_col12" class="data row0 col12" ></td>
#       <td id="T_b994d_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fe43:6d39</td>
#       <td id="T_b994d_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_b994d_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_b994d_row1_col0" class="data row1 col0" >04751694-9c7f-4688-9a29-22c551a24435</td>
#       <td id="T_b994d_row1_col1" class="data row1 col1" >gpu-node2</td>
#       <td id="T_b994d_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_b994d_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_b994d_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_b994d_row1_col5" class="data row1 col5" >default_ubuntu_24</td>
#       <td id="T_b994d_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_b994d_row1_col7" class="data row1 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_b994d_row1_col8" class="data row1 col8" >CERN</td>
#       <td id="T_b994d_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_b994d_row1_col10" class="data row1 col10" >2001:400:a100:3090:f816:3eff:fea7:bb66</td>
#       <td id="T_b994d_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_b994d_row1_col12" class="data row1 col12" ></td>
#       <td id="T_b994d_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fea7:bb66</td>
#       <td id="T_b994d_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_b994d_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c53c8 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_c53c8 th {
#   text-align: left;
# }
# #T_c53c8 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_c53c8 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_c53c8 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_c53c8_row0_col0, #T_c53c8_row0_col1, #T_c53c8_row0_col2, #T_c53c8_row0_col3, #T_c53c8_row0_col4, #T_c53c8_row0_col5, #T_c53c8_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_c53c8_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_c53c8_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_c53c8">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_c53c8_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_c53c8_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_c53c8_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_c53c8_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_c53c8_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_c53c8_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_c53c8_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_c53c8_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_c53c8_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c53c8_row0_col0" class="data row0 col0" >241c2623-305c-4238-86d0-59a5c2b238e5</td>
#       <td id="T_c53c8_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_c53c8_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_c53c8_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_c53c8_row0_col4" class="data row0 col4" >CERN</td>
#       <td id="T_c53c8_row0_col5" class="data row0 col5" >192.168.100.0/24</td>
#       <td id="T_c53c8_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_c53c8_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_c53c8_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_52fd1 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_52fd1 th {
#   text-align: left;
# }
# #T_52fd1 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_52fd1 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_52fd1 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_52fd1_row0_col0, #T_52fd1_row0_col1, #T_52fd1_row0_col2, #T_52fd1_row0_col3, #T_52fd1_row0_col4, #T_52fd1_row0_col5, #T_52fd1_row0_col6, #T_52fd1_row0_col7, #T_52fd1_row0_col8, #T_52fd1_row0_col9, #T_52fd1_row0_col10, #T_52fd1_row0_col11, #T_52fd1_row0_col12, #T_52fd1_row1_col0, #T_52fd1_row1_col1, #T_52fd1_row1_col2, #T_52fd1_row1_col3, #T_52fd1_row1_col4, #T_52fd1_row1_col5, #T_52fd1_row1_col6, #T_52fd1_row1_col7, #T_52fd1_row1_col8, #T_52fd1_row1_col9, #T_52fd1_row1_col10, #T_52fd1_row1_col11, #T_52fd1_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_52fd1">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_52fd1_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_52fd1_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_52fd1_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_52fd1_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_52fd1_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_52fd1_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_52fd1_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_52fd1_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_52fd1_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_52fd1_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_52fd1_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_52fd1_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_52fd1_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_52fd1_row0_col0" class="data row0 col0" >gpu-node1-nic1-p1</td>
#       <td id="T_52fd1_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_52fd1_row0_col2" class="data row0 col2" >gpu-node1</td>
#       <td id="T_52fd1_row0_col3" class="data row0 col3" >net1</td>
#       <td id="T_52fd1_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_52fd1_row0_col5" class="data row0 col5" >auto</td>
#       <td id="T_52fd1_row0_col6" class="data row0 col6" ></td>
#       <td id="T_52fd1_row0_col7" class="data row0 col7" >02:1D:B9:31:E7:23</td>
#       <td id="T_52fd1_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_52fd1_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_52fd1_row0_col10" class="data row0 col10" >192.168.100.2</td>
#       <td id="T_52fd1_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_52fd1_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_52fd1_row1_col0" class="data row1 col0" >gpu-node2-nic1-p1</td>
#       <td id="T_52fd1_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_52fd1_row1_col2" class="data row1 col2" >gpu-node2</td>
#       <td id="T_52fd1_row1_col3" class="data row1 col3" >net1</td>
#       <td id="T_52fd1_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_52fd1_row1_col5" class="data row1 col5" >auto</td>
#       <td id="T_52fd1_row1_col6" class="data row1 col6" ></td>
#       <td id="T_52fd1_row1_col7" class="data row1 col7" >02:B5:53:89:2C:E6</td>
#       <td id="T_52fd1_row1_col8" class="data row1 col8" >enp8s0</td>
#       <td id="T_52fd1_row1_col9" class="data row1 col9" >enp8s0</td>
#       <td id="T_52fd1_row1_col10" class="data row1 col10" >192.168.100.1</td>
#       <td id="T_52fd1_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_52fd1_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 334 seconds

# %% [markdown]
# ## Get the Slice
#
# Retrieve the node information and save the management IP addresses.

# %%
slice = fablib.get_slice(name=slice_name)
slice.show();
# Out:
# <style type="text/css">
# #T_399c8 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_399c8 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_399c8 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_399c8_row0_col0, #T_399c8_row0_col1, #T_399c8_row1_col0, #T_399c8_row1_col1, #T_399c8_row2_col0, #T_399c8_row2_col1, #T_399c8_row3_col0, #T_399c8_row3_col1, #T_399c8_row4_col0, #T_399c8_row4_col1, #T_399c8_row5_col0, #T_399c8_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_399c8">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_399c8_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_399c8_row0_col1" class="data row0 col1" >c02bacf6-d049-4522-8878-8446d8a6a33c</td>
#     </tr>
#     <tr>
#       <td id="T_399c8_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_399c8_row1_col1" class="data row1 col1" >A40-CERN-perf1</td>
#     </tr>
#     <tr>
#       <td id="T_399c8_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_399c8_row2_col1" class="data row2 col1" >2025-01-14 14:47:08 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_399c8_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_399c8_row3_col1" class="data row3 col1" >2025-01-13 14:47:08 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_399c8_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_399c8_row4_col1" class="data row4 col1" >1eb0c915-27b6-4421-aab1-27ae42ded922</td>
#     </tr>
#     <tr>
#       <td id="T_399c8_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_399c8_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Get the Node
#
# Retrieve the node information and save the management IP address.

# %%
node1 = slice.get_node(node1_name) 
node1.show()

node2 = slice.get_node(node2_name) 
node2.show()

gpu1 = node1.get_component('gpu1')
gpu1.show();

gpu2 = node2.get_component('gpu2')
gpu2.show();
# Out:
# <style type="text/css">
# #T_0e2e3 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0e2e3 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0e2e3 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_0e2e3_row0_col0, #T_0e2e3_row0_col1, #T_0e2e3_row1_col0, #T_0e2e3_row1_col1, #T_0e2e3_row2_col0, #T_0e2e3_row2_col1, #T_0e2e3_row3_col0, #T_0e2e3_row3_col1, #T_0e2e3_row4_col0, #T_0e2e3_row4_col1, #T_0e2e3_row5_col0, #T_0e2e3_row5_col1, #T_0e2e3_row6_col0, #T_0e2e3_row6_col1, #T_0e2e3_row7_col0, #T_0e2e3_row7_col1, #T_0e2e3_row8_col0, #T_0e2e3_row8_col1, #T_0e2e3_row9_col0, #T_0e2e3_row9_col1, #T_0e2e3_row10_col0, #T_0e2e3_row10_col1, #T_0e2e3_row11_col0, #T_0e2e3_row11_col1, #T_0e2e3_row12_col0, #T_0e2e3_row12_col1, #T_0e2e3_row13_col0, #T_0e2e3_row13_col1, #T_0e2e3_row14_col0, #T_0e2e3_row14_col1, #T_0e2e3_row15_col0, #T_0e2e3_row15_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_0e2e3">
#   <caption>Node</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0e2e3_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_0e2e3_row0_col1" class="data row0 col1" >7cb0d975-8926-499f-8742-afc4684e4525</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_0e2e3_row1_col1" class="data row1 col1" >gpu-node1</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row2_col0" class="data row2 col0" >Cores</td>
#       <td id="T_0e2e3_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row3_col0" class="data row3 col0" >RAM</td>
#       <td id="T_0e2e3_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row4_col0" class="data row4 col0" >Disk</td>
#       <td id="T_0e2e3_row4_col1" class="data row4 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row5_col0" class="data row5 col0" >Image</td>
#       <td id="T_0e2e3_row5_col1" class="data row5 col1" >default_ubuntu_24</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row6_col0" class="data row6 col0" >Image Type</td>
#       <td id="T_0e2e3_row6_col1" class="data row6 col1" >qcow2</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row7_col0" class="data row7 col0" >Host</td>
#       <td id="T_0e2e3_row7_col1" class="data row7 col1" >cern-w1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row8_col0" class="data row8 col0" >Site</td>
#       <td id="T_0e2e3_row8_col1" class="data row8 col1" >CERN</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row9_col0" class="data row9 col0" >Username</td>
#       <td id="T_0e2e3_row9_col1" class="data row9 col1" >ubuntu</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row10_col0" class="data row10 col0" >Management IP</td>
#       <td id="T_0e2e3_row10_col1" class="data row10 col1" >2001:400:a100:3090:f816:3eff:fe43:6d39</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row11_col0" class="data row11 col0" >State</td>
#       <td id="T_0e2e3_row11_col1" class="data row11 col1" >Active</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row12_col0" class="data row12 col0" >Error</td>
#       <td id="T_0e2e3_row12_col1" class="data row12 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row13_col0" class="data row13 col0" >SSH Command</td>
#       <td id="T_0e2e3_row13_col1" class="data row13 col1" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fe43:6d39</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row14_col0" class="data row14 col0" >Public SSH Key File</td>
#       <td id="T_0e2e3_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_0e2e3_row15_col0" class="data row15 col0" >Private SSH Key File</td>
#       <td id="T_0e2e3_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_03a8a tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_03a8a tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_03a8a caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_03a8a_row0_col0, #T_03a8a_row0_col1, #T_03a8a_row1_col0, #T_03a8a_row1_col1, #T_03a8a_row2_col0, #T_03a8a_row2_col1, #T_03a8a_row3_col0, #T_03a8a_row3_col1, #T_03a8a_row4_col0, #T_03a8a_row4_col1, #T_03a8a_row5_col0, #T_03a8a_row5_col1, #T_03a8a_row6_col0, #T_03a8a_row6_col1, #T_03a8a_row7_col0, #T_03a8a_row7_col1, #T_03a8a_row8_col0, #T_03a8a_row8_col1, #T_03a8a_row9_col0, #T_03a8a_row9_col1, #T_03a8a_row10_col0, #T_03a8a_row10_col1, #T_03a8a_row11_col0, #T_03a8a_row11_col1, #T_03a8a_row12_col0, #T_03a8a_row12_col1, #T_03a8a_row13_col0, #T_03a8a_row13_col1, #T_03a8a_row14_col0, #T_03a8a_row14_col1, #T_03a8a_row15_col0, #T_03a8a_row15_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_03a8a">
#   <caption>Node</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_03a8a_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_03a8a_row0_col1" class="data row0 col1" >04751694-9c7f-4688-9a29-22c551a24435</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_03a8a_row1_col1" class="data row1 col1" >gpu-node2</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row2_col0" class="data row2 col0" >Cores</td>
#       <td id="T_03a8a_row2_col1" class="data row2 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row3_col0" class="data row3 col0" >RAM</td>
#       <td id="T_03a8a_row3_col1" class="data row3 col1" >8</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row4_col0" class="data row4 col0" >Disk</td>
#       <td id="T_03a8a_row4_col1" class="data row4 col1" >100</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row5_col0" class="data row5 col0" >Image</td>
#       <td id="T_03a8a_row5_col1" class="data row5 col1" >default_ubuntu_24</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row6_col0" class="data row6 col0" >Image Type</td>
#       <td id="T_03a8a_row6_col1" class="data row6 col1" >qcow2</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row7_col0" class="data row7 col0" >Host</td>
#       <td id="T_03a8a_row7_col1" class="data row7 col1" >cern-w1.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row8_col0" class="data row8 col0" >Site</td>
#       <td id="T_03a8a_row8_col1" class="data row8 col1" >CERN</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row9_col0" class="data row9 col0" >Username</td>
#       <td id="T_03a8a_row9_col1" class="data row9 col1" >ubuntu</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row10_col0" class="data row10 col0" >Management IP</td>
#       <td id="T_03a8a_row10_col1" class="data row10 col1" >2001:400:a100:3090:f816:3eff:fea7:bb66</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row11_col0" class="data row11 col0" >State</td>
#       <td id="T_03a8a_row11_col1" class="data row11 col1" >Active</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row12_col0" class="data row12 col0" >Error</td>
#       <td id="T_03a8a_row12_col1" class="data row12 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row13_col0" class="data row13 col0" >SSH Command</td>
#       <td id="T_03a8a_row13_col1" class="data row13 col1" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fea7:bb66</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row14_col0" class="data row14 col0" >Public SSH Key File</td>
#       <td id="T_03a8a_row14_col1" class="data row14 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_03a8a_row15_col0" class="data row15 col0" >Private SSH Key File</td>
#       <td id="T_03a8a_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e211d tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e211d tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e211d caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_e211d_row0_col0, #T_e211d_row0_col1, #T_e211d_row1_col0, #T_e211d_row1_col1, #T_e211d_row2_col0, #T_e211d_row2_col1, #T_e211d_row3_col0, #T_e211d_row3_col1, #T_e211d_row4_col0, #T_e211d_row4_col1, #T_e211d_row5_col0, #T_e211d_row5_col1, #T_e211d_row6_col0, #T_e211d_row6_col1, #T_e211d_row7_col0, #T_e211d_row7_col1, #T_e211d_row8_col0, #T_e211d_row8_col1, #T_e211d_row9_col0, #T_e211d_row9_col1, #T_e211d_row10_col0, #T_e211d_row10_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_e211d">
#   <caption>Component</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e211d_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_e211d_row0_col1" class="data row0 col1" >gpu-node1-gpu1</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row1_col0" class="data row1 col0" >Short Name</td>
#       <td id="T_e211d_row1_col1" class="data row1 col1" >gpu1</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row2_col0" class="data row2 col0" >Details</td>
#       <td id="T_e211d_row2_col1" class="data row2 col1" >NVIDIA Corporation GA102GL [A40] (rev a1)</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row3_col0" class="data row3 col0" >Disk</td>
#       <td id="T_e211d_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row4_col0" class="data row4 col0" >Units</td>
#       <td id="T_e211d_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row5_col0" class="data row5 col0" >PCI Address</td>
#       <td id="T_e211d_row5_col1" class="data row5 col1" >['0000:08:00.0']</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row6_col0" class="data row6 col0" >Model</td>
#       <td id="T_e211d_row6_col1" class="data row6 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row7_col0" class="data row7 col0" >Type</td>
#       <td id="T_e211d_row7_col1" class="data row7 col1" >GPU</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row8_col0" class="data row8 col0" >Device</td>
#       <td id="T_e211d_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row9_col0" class="data row9 col0" >Node</td>
#       <td id="T_e211d_row9_col1" class="data row9 col1" >gpu-node1</td>
#     </tr>
#     <tr>
#       <td id="T_e211d_row10_col0" class="data row10 col0" >Numa Node</td>
#       <td id="T_e211d_row10_col1" class="data row10 col1" >2</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_1d632 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_1d632 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_1d632 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_1d632_row0_col0, #T_1d632_row0_col1, #T_1d632_row1_col0, #T_1d632_row1_col1, #T_1d632_row2_col0, #T_1d632_row2_col1, #T_1d632_row3_col0, #T_1d632_row3_col1, #T_1d632_row4_col0, #T_1d632_row4_col1, #T_1d632_row5_col0, #T_1d632_row5_col1, #T_1d632_row6_col0, #T_1d632_row6_col1, #T_1d632_row7_col0, #T_1d632_row7_col1, #T_1d632_row8_col0, #T_1d632_row8_col1, #T_1d632_row9_col0, #T_1d632_row9_col1, #T_1d632_row10_col0, #T_1d632_row10_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_1d632">
#   <caption>Component</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1d632_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_1d632_row0_col1" class="data row0 col1" >gpu-node2-gpu2</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row1_col0" class="data row1 col0" >Short Name</td>
#       <td id="T_1d632_row1_col1" class="data row1 col1" >gpu2</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row2_col0" class="data row2 col0" >Details</td>
#       <td id="T_1d632_row2_col1" class="data row2 col1" >NVIDIA Corporation GA102GL [A40] (rev a1)</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row3_col0" class="data row3 col0" >Disk</td>
#       <td id="T_1d632_row3_col1" class="data row3 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row4_col0" class="data row4 col0" >Units</td>
#       <td id="T_1d632_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row5_col0" class="data row5 col0" >PCI Address</td>
#       <td id="T_1d632_row5_col1" class="data row5 col1" >['0000:07:00.0']</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row6_col0" class="data row6 col0" >Model</td>
#       <td id="T_1d632_row6_col1" class="data row6 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row7_col0" class="data row7 col0" >Type</td>
#       <td id="T_1d632_row7_col1" class="data row7 col1" >GPU</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row8_col0" class="data row8 col0" >Device</td>
#       <td id="T_1d632_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row9_col0" class="data row9 col0" >Node</td>
#       <td id="T_1d632_row9_col1" class="data row9 col1" >gpu-node2</td>
#     </tr>
#     <tr>
#       <td id="T_1d632_row10_col0" class="data row10 col0" >Numa Node</td>
#       <td id="T_1d632_row10_col1" class="data row10 col1" >7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## GPU PCI Device
#
# Run the command <code>lspci</code> to see your GPU PCI device(s). This is the raw GPU PCI device that is not yet configured for use.  You can use the GPUs as you would any GPUs.
#
# View node's GPU

# %%
command = "sudo apt-get install -y pciutils && lspci | grep 'NVIDIA'"

stdout, stderr = node1.execute(command)
stdout, stderr = node2.execute(command)
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# pciutils is already the newest version (1:3.10.0-2build1).
# pciutils set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# 08:00.0 3D controller: NVIDIA Corporation GA102GL [A40] (rev a1)
# Reading package lists...
# Building dependency tree...
# Reading state information...
# pciutils is already the newest version (1:3.10.0-2build1).
# pciutils set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# 07:00.0 3D controller: NVIDIA Corporation GA102GL [A40] (rev a1)

# %% [markdown]
# ## Install Nvidia Drivers
#
# Now, let's run the following commands to install the latest NVidia driver and the CUDA libraries and compiler. This step can take up to 20 minutes.
#
# NOTE: for instructional purposes the following cell sends all command output back to the notebook. You can also send it to log files to keep the notebook output clean.

# %%
distro='ubuntu2404'
version='12.6'
architecture='x86_64'

# install prerequisites
commands = [
    'sudo apt-get -q update',
    'sudo apt-get -q install -y linux-headers-$(uname -r) gcc',
]

print("Installing Prerequisites...")
for command in commands:
    print(f"++++ {command}")
    stdout, stderr = node1.execute(command)
    print(f"++++ {command}")
    stdout, stderr = node2.execute(command)

print(f"Installing CUDA {version}")
commands = [
    f'wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-keyring_1.1-1_all.deb',
    f'sudo dpkg -i cuda-keyring_1.1-1_all.deb',
    'sudo apt-get -q update',
    'sudo apt-get -q install -y cuda'
]
print("Installing CUDA...")
for command in commands:
    print(f"++++ {command}")
    stdout, stderr = node1.execute(command)
    print(f"++++ {command}")
    stdout, stderr = node2.execute(command)
    
print("Done installing CUDA")
# Out:
# Installing Prerequisites...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:2 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:3 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [585 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 Packages [15.0 MB]
# Get:7 http://security.ubuntu.com/ubuntu noble-security/main Translation-en [114 kB]
# Get:8 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [7288 B]
# Get:9 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [800 kB]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/universe Translation-en [171 kB]
# Get:11 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [52.0 kB]
# Get:12 http://security.ubuntu.com/ubuntu noble-security/universe amd64 c-n-f Metadata [13.5 kB]
# Get:13 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [572 kB]
# Get:14 http://security.ubuntu.com/ubuntu noble-security/restricted Translation-en [110 kB]
# Get:15 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [212 B]
# Get:16 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [12.4 kB]
# Get:17 http://security.ubuntu.com/ubuntu noble-security/multiverse Translation-en [2940 B]
# Get:18 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [212 B]
# Get:19 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 c-n-f Metadata [356 B]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe Translation-en [5982 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 Components [3871 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 c-n-f Metadata [301 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse amd64 Packages [269 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse Translation-en [118 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse amd64 Components [35.0 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse amd64 c-n-f Metadata [8328 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [770 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main Translation-en [174 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 Components [151 kB]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [972 kB]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe Translation-en [241 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe amd64 Components [309 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe amd64 c-n-f Metadata [19.9 kB]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [583 kB]
# Get:35 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/restricted Translation-en [113 kB]
# Get:36 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Components [212 B]
# Get:37 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [16.0 kB]
# Get:38 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse Translation-en [3844 B]
# Get:39 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Components [940 B]
# Get:40 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 c-n-f Metadata [552 B]
# Get:41 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/main amd64 Components [208 B]
# Get:42 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/main amd64 c-n-f Metadata [112 B]
# Get:43 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [10.7 kB]
# Get:44 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe Translation-en [10.8 kB]
# Get:45 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe amd64 Components [11.7 kB]
# Get:46 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe amd64 c-n-f Metadata [1104 B]
# Get:47 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/restricted amd64 Components [216 B]
# Get:48 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:49 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 Components [212 B]
# Get:50 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 32.1 MB in 5s (5993 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:2 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Get:5 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [585 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 Packages [15.0 MB]
# Get:7 http://security.ubuntu.com/ubuntu noble-security/main Translation-en [114 kB]
# Get:8 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [7288 B]
# Get:9 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [800 kB]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/universe Translation-en [171 kB]
# Get:11 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [52.0 kB]
# Get:12 http://security.ubuntu.com/ubuntu noble-security/universe amd64 c-n-f Metadata [13.5 kB]
# Get:13 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Packages [572 kB]
# Get:14 http://security.ubuntu.com/ubuntu noble-security/restricted Translation-en [110 kB]
# Get:15 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [212 B]
# Get:16 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Packages [12.4 kB]
# Get:17 http://security.ubuntu.com/ubuntu noble-security/multiverse Translation-en [2940 B]
# Get:18 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [212 B]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe Translation-en [5982 kB]
# Get:20 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 c-n-f Metadata [356 B]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 Components [3871 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 c-n-f Metadata [301 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse amd64 Packages [269 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse Translation-en [118 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse amd64 Components [35.0 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu noble/multiverse amd64 c-n-f Metadata [8328 B]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 Packages [770 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main Translation-en [174 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 Components [151 kB]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe amd64 Packages [972 kB]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe Translation-en [241 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe amd64 Components [309 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/universe amd64 c-n-f Metadata [19.9 kB]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Packages [583 kB]
# Get:35 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/restricted Translation-en [113 kB]
# Get:36 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/restricted amd64 Components [212 B]
# Get:37 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Packages [16.0 kB]
# Get:38 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse Translation-en [3844 B]
# Get:39 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 Components [940 B]
# Get:40 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/multiverse amd64 c-n-f Metadata [552 B]
# Get:41 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/main amd64 Components [208 B]
# Get:42 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/main amd64 c-n-f Metadata [112 B]
# Get:43 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe amd64 Packages [10.7 kB]
# Get:44 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe Translation-en [10.8 kB]
# Get:45 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe amd64 Components [11.7 kB]
# Get:46 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/universe amd64 c-n-f Metadata [1104 B]
# Get:47 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/restricted amd64 Components [216 B]
# Get:48 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/restricted amd64 c-n-f Metadata [116 B]
# Get:49 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 Components [212 B]
# Get:50 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports/multiverse amd64 c-n-f Metadata [116 B]
# Fetched 32.1 MB in 5s (6152 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q install -y linux-headers-$(uname -r) gcc
# Reading package lists...
# Building dependency tree...
# Reading state information...
# linux-headers-6.8.0-49-generic is already the newest version (6.8.0-49.49).
# linux-headers-6.8.0-49-generic set to manually installed.
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu cpp cpp-13
#   cpp-13-x86-64-linux-gnu cpp-x86-64-linux-gnu gcc-13 gcc-13-base
#   gcc-13-x86-64-linux-gnu gcc-x86-64-linux-gnu libasan8 libatomic1 libbinutils
#   libcc1-0 libctf-nobfd0 libctf0 libgcc-13-dev libgomp1 libgprofng0 libhwasan0
#   libisl23 libitm1 liblsan0 libmpc3 libquadmath0 libsframe1 libtsan2 libubsan1
# Suggested packages:
#   binutils-doc gprofng-gui cpp-doc gcc-13-locales cpp-13-doc gcc-multilib make
#   autoconf automake libtool flex bison gdb gcc-doc gcc-13-multilib gcc-13-doc
#   gdb-x86-64-linux-gnu
# The following NEW packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu cpp cpp-13
#   cpp-13-x86-64-linux-gnu cpp-x86-64-linux-gnu gcc gcc-13 gcc-13-base
#   gcc-13-x86-64-linux-gnu gcc-x86-64-linux-gnu libasan8 libatomic1 libbinutils
#   libcc1-0 libctf-nobfd0 libctf0 libgcc-13-dev libgomp1 libgprofng0 libhwasan0
#   libisl23 libitm1 liblsan0 libmpc3 libquadmath0 libsframe1 libtsan2 libubsan1
# 0 upgraded, 30 newly installed, 0 to remove and 32 not upgraded.
# Need to get 50.5 MB of archives.
# After this operation, 167 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 binutils-common amd64 2.42-4ubuntu2.3 [239 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libsframe1 amd64 2.42-4ubuntu2.3 [14.9 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libbinutils amd64 2.42-4ubuntu2.3 [575 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libctf-nobfd0 amd64 2.42-4ubuntu2.3 [97.1 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libctf0 amd64 2.42-4ubuntu2.3 [94.5 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgprofng0 amd64 2.42-4ubuntu2.3 [849 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.42-4ubuntu2.3 [2463 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 binutils amd64 2.42-4ubuntu2.3 [18.1 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gcc-13-base amd64 13.3.0-6ubuntu2~24.04 [51.5 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libisl23 amd64 0.26-3build1 [680 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libmpc3 amd64 1.3.1-1build1 [54.5 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 cpp-13-x86-64-linux-gnu amd64 13.3.0-6ubuntu2~24.04 [10.7 MB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 cpp-13 amd64 13.3.0-6ubuntu2~24.04 [1038 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 cpp-x86-64-linux-gnu amd64 4:13.2.0-7ubuntu1 [5326 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 cpp amd64 4:13.2.0-7ubuntu1 [22.4 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcc1-0 amd64 14.2.0-4ubuntu2~24.04 [48.0 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgomp1 amd64 14.2.0-4ubuntu2~24.04 [148 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libitm1 amd64 14.2.0-4ubuntu2~24.04 [29.7 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libatomic1 amd64 14.2.0-4ubuntu2~24.04 [10.5 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libasan8 amd64 14.2.0-4ubuntu2~24.04 [3031 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 liblsan0 amd64 14.2.0-4ubuntu2~24.04 [1322 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libtsan2 amd64 14.2.0-4ubuntu2~24.04 [2772 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libubsan1 amd64 14.2.0-4ubuntu2~24.04 [1184 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libhwasan0 amd64 14.2.0-4ubuntu2~24.04 [1641 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libquadmath0 amd64 14.2.0-4ubuntu2~24.04 [153 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgcc-13-dev amd64 13.3.0-6ubuntu2~24.04 [2681 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gcc-13-x86-64-linux-gnu amd64 13.3.0-6ubuntu2~24.04 [21.1 MB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gcc-13 amd64 13.3.0-6ubuntu2~24.04 [494 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 gcc-x86-64-linux-gnu amd64 4:13.2.0-7ubuntu1 [1212 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 gcc amd64 4:13.2.0-7ubuntu1 [5018 B]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#  Fetched 50.5 MB in 3s (18.8 MB/s)
#  dpkg-preconfigure: unable to re-open stdin:
#  Selecting previously unselected package binutils-common:amd64.
# (Reading database ... 74727 files and directories currently installed.)
# Preparing to unpack .../00-binutils-common_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking binutils-common:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libsframe1:amd64.
# Preparing to unpack .../01-libsframe1_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libsframe1:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../02-libbinutils_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libbinutils:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../03-libctf-nobfd0_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../04-libctf0_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libctf0:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libgprofng0:amd64.
# Preparing to unpack .../05-libgprofng0_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libgprofng0:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../06-binutils-x86-64-linux-gnu_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.42-4ubuntu2.3) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../07-binutils_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking binutils (2.42-4ubuntu2.3) ...
# Selecting previously unselected package gcc-13-base:amd64.
# Preparing to unpack .../08-gcc-13-base_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking gcc-13-base:amd64 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package libisl23:amd64.
# Preparing to unpack .../09-libisl23_0.26-3build1_amd64.deb ...
# Unpacking libisl23:amd64 (0.26-3build1) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../10-libmpc3_1.3.1-1build1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.3.1-1build1) ...
# Selecting previously unselected package cpp-13-x86-64-linux-gnu.
# Preparing to unpack .../11-cpp-13-x86-64-linux-gnu_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking cpp-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package cpp-13.
# Preparing to unpack .../12-cpp-13_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking cpp-13 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package cpp-x86-64-linux-gnu.
# Preparing to unpack .../13-cpp-x86-64-linux-gnu_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking cpp-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../14-cpp_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking cpp (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../15-libcc1-0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libcc1-0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../16-libgomp1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libgomp1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../17-libitm1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libitm1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../18-libatomic1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libatomic1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../19-libasan8_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libasan8:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../20-liblsan0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking liblsan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../21-libtsan2_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libtsan2:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../22-libubsan1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libubsan1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libhwasan0:amd64.
# Preparing to unpack .../23-libhwasan0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libhwasan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../24-libquadmath0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libquadmath0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libgcc-13-dev:amd64.
# Preparing to unpack .../25-libgcc-13-dev_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking libgcc-13-dev:amd64 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package gcc-13-x86-64-linux-gnu.
# Preparing to unpack .../26-gcc-13-x86-64-linux-gnu_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking gcc-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package gcc-13.
# Preparing to unpack .../27-gcc-13_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking gcc-13 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package gcc-x86-64-linux-gnu.
# Preparing to unpack .../28-gcc-x86-64-linux-gnu_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking gcc-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../29-gcc_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking gcc (4:13.2.0-7ubuntu1) ...
# Setting up binutils-common:amd64 (2.42-4ubuntu2.3) ...
# Setting up libctf-nobfd0:amd64 (2.42-4ubuntu2.3) ...
# Setting up libgomp1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libsframe1:amd64 (2.42-4ubuntu2.3) ...
# Setting up gcc-13-base:amd64 (13.3.0-6ubuntu2~24.04) ...
# Setting up libquadmath0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libmpc3:amd64 (1.3.1-1build1) ...
# Setting up libatomic1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libubsan1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libhwasan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libasan8:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libtsan2:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libbinutils:amd64 (2.42-4ubuntu2.3) ...
# Setting up libisl23:amd64 (0.26-3build1) ...
# Setting up libcc1-0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up liblsan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libitm1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libctf0:amd64 (2.42-4ubuntu2.3) ...
# Setting up cpp-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Setting up libgprofng0:amd64 (2.42-4ubuntu2.3) ...
# Setting up libgcc-13-dev:amd64 (13.3.0-6ubuntu2~24.04) ...
# Setting up binutils-x86-64-linux-gnu (2.42-4ubuntu2.3) ...
# Setting up cpp-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Setting up cpp-13 (13.3.0-6ubuntu2~24.04) ...
# Setting up gcc-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Setting up binutils (2.42-4ubuntu2.3) ...
# Setting up gcc-13 (13.3.0-6ubuntu2~24.04) ...
# Setting up cpp (4:13.2.0-7ubuntu1) ...
# Setting up gcc-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Setting up gcc (4:13.2.0-7ubuntu1) ...
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.3) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#  ++++ sudo apt-get -q install -y linux-headers-$(uname -r) gcc
# Reading package lists...
# Building dependency tree...
# Reading state information...
# linux-headers-6.8.0-49-generic is already the newest version (6.8.0-49.49).
# linux-headers-6.8.0-49-generic set to manually installed.
# The following additional packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu cpp cpp-13
#   cpp-13-x86-64-linux-gnu cpp-x86-64-linux-gnu gcc-13 gcc-13-base
#   gcc-13-x86-64-linux-gnu gcc-x86-64-linux-gnu libasan8 libatomic1 libbinutils
#   libcc1-0 libctf-nobfd0 libctf0 libgcc-13-dev libgomp1 libgprofng0 libhwasan0
#   libisl23 libitm1 liblsan0 libmpc3 libquadmath0 libsframe1 libtsan2 libubsan1
# Suggested packages:
#   binutils-doc gprofng-gui cpp-doc gcc-13-locales cpp-13-doc gcc-multilib make
#   autoconf automake libtool flex bison gdb gcc-doc gcc-13-multilib gcc-13-doc
#   gdb-x86-64-linux-gnu
# The following NEW packages will be installed:
#   binutils binutils-common binutils-x86-64-linux-gnu cpp cpp-13
#   cpp-13-x86-64-linux-gnu cpp-x86-64-linux-gnu gcc gcc-13 gcc-13-base
#   gcc-13-x86-64-linux-gnu gcc-x86-64-linux-gnu libasan8 libatomic1 libbinutils
#   libcc1-0 libctf-nobfd0 libctf0 libgcc-13-dev libgomp1 libgprofng0 libhwasan0
#   libisl23 libitm1 liblsan0 libmpc3 libquadmath0 libsframe1 libtsan2 libubsan1
# 0 upgraded, 30 newly installed, 0 to remove and 32 not upgraded.
# Need to get 50.5 MB of archives.
# After this operation, 167 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 binutils-common amd64 2.42-4ubuntu2.3 [239 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libsframe1 amd64 2.42-4ubuntu2.3 [14.9 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libbinutils amd64 2.42-4ubuntu2.3 [575 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libctf-nobfd0 amd64 2.42-4ubuntu2.3 [97.1 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libctf0 amd64 2.42-4ubuntu2.3 [94.5 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgprofng0 amd64 2.42-4ubuntu2.3 [849 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 binutils-x86-64-linux-gnu amd64 2.42-4ubuntu2.3 [2463 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 binutils amd64 2.42-4ubuntu2.3 [18.1 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gcc-13-base amd64 13.3.0-6ubuntu2~24.04 [51.5 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libisl23 amd64 0.26-3build1 [680 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libmpc3 amd64 1.3.1-1build1 [54.5 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 cpp-13-x86-64-linux-gnu amd64 13.3.0-6ubuntu2~24.04 [10.7 MB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 cpp-13 amd64 13.3.0-6ubuntu2~24.04 [1038 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 cpp-x86-64-linux-gnu amd64 4:13.2.0-7ubuntu1 [5326 B]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 cpp amd64 4:13.2.0-7ubuntu1 [22.4 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcc1-0 amd64 14.2.0-4ubuntu2~24.04 [48.0 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgomp1 amd64 14.2.0-4ubuntu2~24.04 [148 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libitm1 amd64 14.2.0-4ubuntu2~24.04 [29.7 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libatomic1 amd64 14.2.0-4ubuntu2~24.04 [10.5 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libasan8 amd64 14.2.0-4ubuntu2~24.04 [3031 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 liblsan0 amd64 14.2.0-4ubuntu2~24.04 [1322 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libtsan2 amd64 14.2.0-4ubuntu2~24.04 [2772 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libubsan1 amd64 14.2.0-4ubuntu2~24.04 [1184 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libhwasan0 amd64 14.2.0-4ubuntu2~24.04 [1641 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libquadmath0 amd64 14.2.0-4ubuntu2~24.04 [153 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgcc-13-dev amd64 13.3.0-6ubuntu2~24.04 [2681 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gcc-13-x86-64-linux-gnu amd64 13.3.0-6ubuntu2~24.04 [21.1 MB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gcc-13 amd64 13.3.0-6ubuntu2~24.04 [494 kB]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 gcc-x86-64-linux-gnu amd64 4:13.2.0-7ubuntu1 [1212 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 gcc amd64 4:13.2.0-7ubuntu1 [5018 B]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 50.5 MB in 2min 10s (390 kB/s)
# Selecting previously unselected package binutils-common:amd64.
# (Reading database ... 74727 files and directories currently installed.)
# Preparing to unpack .../00-binutils-common_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking binutils-common:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libsframe1:amd64.
# Preparing to unpack .../01-libsframe1_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libsframe1:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libbinutils:amd64.
# Preparing to unpack .../02-libbinutils_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libbinutils:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libctf-nobfd0:amd64.
# Preparing to unpack .../03-libctf-nobfd0_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libctf-nobfd0:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libctf0:amd64.
# Preparing to unpack .../04-libctf0_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libctf0:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package libgprofng0:amd64.
# Preparing to unpack .../05-libgprofng0_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking libgprofng0:amd64 (2.42-4ubuntu2.3) ...
# Selecting previously unselected package binutils-x86-64-linux-gnu.
# Preparing to unpack .../06-binutils-x86-64-linux-gnu_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking binutils-x86-64-linux-gnu (2.42-4ubuntu2.3) ...
# Selecting previously unselected package binutils.
# Preparing to unpack .../07-binutils_2.42-4ubuntu2.3_amd64.deb ...
# Unpacking binutils (2.42-4ubuntu2.3) ...
# Selecting previously unselected package gcc-13-base:amd64.
# Preparing to unpack .../08-gcc-13-base_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking gcc-13-base:amd64 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package libisl23:amd64.
# Preparing to unpack .../09-libisl23_0.26-3build1_amd64.deb ...
# Unpacking libisl23:amd64 (0.26-3build1) ...
# Selecting previously unselected package libmpc3:amd64.
# Preparing to unpack .../10-libmpc3_1.3.1-1build1_amd64.deb ...
# Unpacking libmpc3:amd64 (1.3.1-1build1) ...
# Selecting previously unselected package cpp-13-x86-64-linux-gnu.
# Preparing to unpack .../11-cpp-13-x86-64-linux-gnu_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking cpp-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package cpp-13.
# Preparing to unpack .../12-cpp-13_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking cpp-13 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package cpp-x86-64-linux-gnu.
# Preparing to unpack .../13-cpp-x86-64-linux-gnu_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking cpp-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package cpp.
# Preparing to unpack .../14-cpp_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking cpp (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package libcc1-0:amd64.
# Preparing to unpack .../15-libcc1-0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libcc1-0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libgomp1:amd64.
# Preparing to unpack .../16-libgomp1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libgomp1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libitm1:amd64.
# Preparing to unpack .../17-libitm1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libitm1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libatomic1:amd64.
# Preparing to unpack .../18-libatomic1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libatomic1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libasan8:amd64.
# Preparing to unpack .../19-libasan8_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libasan8:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package liblsan0:amd64.
# Preparing to unpack .../20-liblsan0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking liblsan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libtsan2:amd64.
# Preparing to unpack .../21-libtsan2_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libtsan2:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libubsan1:amd64.
# Preparing to unpack .../22-libubsan1_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libubsan1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libhwasan0:amd64.
# Preparing to unpack .../23-libhwasan0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libhwasan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libquadmath0:amd64.
# Preparing to unpack .../24-libquadmath0_14.2.0-4ubuntu2~24.04_amd64.deb ...
# Unpacking libquadmath0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Selecting previously unselected package libgcc-13-dev:amd64.
# Preparing to unpack .../25-libgcc-13-dev_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking libgcc-13-dev:amd64 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package gcc-13-x86-64-linux-gnu.
# Preparing to unpack .../26-gcc-13-x86-64-linux-gnu_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking gcc-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package gcc-13.
# Preparing to unpack .../27-gcc-13_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking gcc-13 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package gcc-x86-64-linux-gnu.
# Preparing to unpack .../28-gcc-x86-64-linux-gnu_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking gcc-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package gcc.
# Preparing to unpack .../29-gcc_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking gcc (4:13.2.0-7ubuntu1) ...
# Setting up binutils-common:amd64 (2.42-4ubuntu2.3) ...
# Setting up libctf-nobfd0:amd64 (2.42-4ubuntu2.3) ...
# Setting up libgomp1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libsframe1:amd64 (2.42-4ubuntu2.3) ...
# Setting up gcc-13-base:amd64 (13.3.0-6ubuntu2~24.04) ...
# Setting up libquadmath0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libmpc3:amd64 (1.3.1-1build1) ...
# Setting up libatomic1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libubsan1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libhwasan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libasan8:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libtsan2:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libbinutils:amd64 (2.42-4ubuntu2.3) ...
# Setting up libisl23:amd64 (0.26-3build1) ...
# Setting up libcc1-0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up liblsan0:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libitm1:amd64 (14.2.0-4ubuntu2~24.04) ...
# Setting up libctf0:amd64 (2.42-4ubuntu2.3) ...
# Setting up cpp-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Setting up libgprofng0:amd64 (2.42-4ubuntu2.3) ...
# Setting up libgcc-13-dev:amd64 (13.3.0-6ubuntu2~24.04) ...
# Setting up binutils-x86-64-linux-gnu (2.42-4ubuntu2.3) ...
# Setting up cpp-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Setting up cpp-13 (13.3.0-6ubuntu2~24.04) ...
# Setting up gcc-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Setting up binutils (2.42-4ubuntu2.3) ...
# Setting up gcc-13 (13.3.0-6ubuntu2~24.04) ...
# Setting up cpp (4:13.2.0-7ubuntu1) ...
# Setting up gcc-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Setting up gcc (4:13.2.0-7ubuntu1) ...
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.3) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#  Installing CUDA 12.6
# Installing CUDA...
# ++++ wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-keyring_1.1-1_all.deb
#  --2025-01-13 14:55:45--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-keyring_1.1-1_all.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 2600:2701:5000:5001::17d4:f956, 2600:2701:5000:5001::17d4:f949, 23.212.249.86, ...
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|2600:2701:5000:5001::17d4:f956|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4328 (4.2K) [application/x-deb]
# Saving to: ‘cuda-keyring_1.1-1_all.deb’
#
#      0K ....                                                  100% 1.23G=0s
#
# 2025-01-13 14:55:46 (1.23 GB/s) - ‘cuda-keyring_1.1-1_all.deb’ saved [4328/4328]
#
#  ++++ wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-keyring_1.1-1_all.deb
#  --2025-01-13 14:55:48--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64/cuda-keyring_1.1-1_all.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 2600:2701:5000:5001::17c2:74a3, 2600:2701:5000:5001::17c2:7488, 23.194.116.136, ...
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|2600:2701:5000:5001::17c2:74a3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4328 (4.2K) [application/x-deb]
# Saving to: ‘cuda-keyring_1.1-1_all.deb’
#
#      0K ....                                                  100% 1.46G=0s
#
# 2025-01-13 14:55:51 (1.46 GB/s) - ‘cuda-keyring_1.1-1_all.deb’ saved [4328/4328]
#
#  ++++ sudo dpkg -i cuda-keyring_1.1-1_all.deb
# Selecting previously unselected package cuda-keyring.
# (Reading database ... 75349 files and directories currently installed.)
# Preparing to unpack cuda-keyring_1.1-1_all.deb ...
# Unpacking cuda-keyring (1.1-1) ...
# Setting up cuda-keyring (1.1-1) ...
# ++++ sudo dpkg -i cuda-keyring_1.1-1_all.deb
# Selecting previously unselected package cuda-keyring.
# (Reading database ... 75349 files and directories currently installed.)
# Preparing to unpack cuda-keyring_1.1-1_all.deb ...
# Unpacking cuda-keyring (1.1-1) ...
# Setting up cuda-keyring (1.1-1) ...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Hit:2 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease [1581 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  Packages [308 kB]
# Fetched 565 kB in 2s (247 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Hit:2 http://security.ubuntu.com/ubuntu noble-security InRelease
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Hit:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease [1581 B]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  Packages [308 kB]
# Fetched 691 kB in 4s (170 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q install -y cuda
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Some packages could not be installed. This may mean that you have
# requested an impossible situation or if you are using the unstable
# distribution that some required packages have not yet been created
# or been moved out of Incoming.
# The following information may help to resolve the situation:
#
# The following packages have unmet dependencies:
#  nvidia-open : Depends: nvidia-driver-565-open (>= 565.57.01) but it is not installable or
#                         nvidia-driver-565-server-open (>= 565.57.01) but it is not installable
#  E: Unable to correct problems, you have held broken packages.
#  ++++ sudo apt-get -q install -y cuda
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Some packages could not be installed. This may mean that you have
# requested an impossible situation or if you are using the unstable
# distribution that some required packages have not yet been created
# or been moved out of Incoming.
# The following information may help to resolve the situation:
#
# The following packages have unmet dependencies:
#  nvidia-open : Depends: nvidia-driver-565-open (>= 565.57.01) but it is not installable or
#                         nvidia-driver-565-server-open (>= 565.57.01) but it is not installable
#  E: Unable to correct problems, you have held broken packages.
#  Done installing CUDA

# %%
print(f"Installing cuda-toolkit")
commands = [
    'sudo apt-get -q update',
    'sudo apt-get -q install -y cuda-toolkit'
]
print("Installing cuda-toolkit...")
for command in commands:
    print(f"++++ {command}")
    stdout, stderr = node1.execute(command)
    print(f"++++ {command}")
    stdout, stderr = node2.execute(command)
    
print("Done installing cuda-toolkit")
# Out:
# Installing cuda-toolkit
# Installing cuda-toolkit...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Hit:2 http://security.ubuntu.com/ubuntu noble-security InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease [126 kB]
# Fetched 508 kB in 1s (357 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Hit:2 http://security.ubuntu.com/ubuntu noble-security InRelease
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease [126 kB]
# Hit:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Fetched 382 kB in 13s (29.4 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q install -y cuda-toolkit
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   adwaita-icon-theme alsa-topology-conf alsa-ucm-conf at-spi2-common
#   at-spi2-core build-essential bzip2 ca-certificates-java cuda-cccl-12-6
#   cuda-command-line-tools-12-6 cuda-compiler-12-6 cuda-crt-12-6
#   cuda-cudart-12-6 cuda-cudart-dev-12-6 cuda-cuobjdump-12-6 cuda-cupti-12-6
#   cuda-cupti-dev-12-6 cuda-cuxxfilt-12-6 cuda-documentation-12-6
#   cuda-driver-dev-12-6 cuda-gdb-12-6 cuda-libraries-12-6
#   cuda-libraries-dev-12-6 cuda-nsight-12-6 cuda-nsight-compute-12-6
#   cuda-nsight-systems-12-6 cuda-nvcc-12-6 cuda-nvdisasm-12-6
#   cuda-nvml-dev-12-6 cuda-nvprof-12-6 cuda-nvprune-12-6 cuda-nvrtc-12-6
#   cuda-nvrtc-dev-12-6 cuda-nvtx-12-6 cuda-nvvm-12-6 cuda-nvvp-12-6
#   cuda-opencl-12-6 cuda-opencl-dev-12-6 cuda-profiler-api-12-6
#   cuda-sanitizer-12-6 cuda-toolkit-12-6 cuda-toolkit-12-6-config-common
#   cuda-toolkit-12-config-common cuda-toolkit-config-common cuda-tools-12-6
#   cuda-visual-tools-12-6 dconf-gsettings-backend dconf-service default-jre
#   default-jre-headless dpkg-dev fakeroot fontconfig fonts-dejavu-extra g++
#   g++-13 g++-13-x86-64-linux-gnu g++-x86-64-linux-gnu gds-tools-12-6
#   gsettings-desktop-schemas gtk-update-icon-cache hicolor-icon-theme
#   humanity-icon-theme java-common libalgorithm-diff-perl
#   libalgorithm-diff-xs-perl libalgorithm-merge-perl libasound2-data
#   libasound2t64 libatk-bridge2.0-0t64 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0t64 libatspi2.0-0t64 libavahi-client3
#   libavahi-common-data libavahi-common3 libcairo-gobject2 libcairo2 libcolord2
#   libcublas-12-6 libcublas-dev-12-6 libcufft-12-6 libcufft-dev-12-6
#   libcufile-12-6 libcufile-dev-12-6 libcups2t64 libcurand-12-6
#   libcurand-dev-12-6 libcusolver-12-6 libcusolver-dev-12-6 libcusparse-12-6
#   libcusparse-dev-12-6 libdatrie1 libdconf1 libdpkg-perl libdrm-amdgpu1
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libegl-mesa0 libegl1 libepoxy0
#   libfakeroot libfile-fcntllock-perl libgbm1 libgdk-pixbuf-2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgif7 libgl1 libgl1-amber-dri
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgraphite2-3
#   libgtk-3-0t64 libgtk-3-bin libgtk-3-common libharfbuzz0b libice6 liblcms2-2
#   libllvm17t64 libnpp-12-6 libnpp-dev-12-6 libnvfatbin-12-6
#   libnvfatbin-dev-12-6 libnvjitlink-12-6 libnvjitlink-dev-12-6 libnvjpeg-12-6
#   libnvjpeg-dev-12-6 libopengl0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess0 libpcsclite1 libpixman-1-0 librsvg2-2
#   librsvg2-common libsm6 libstdc++-13-dev libthai-data libthai0 libvulkan1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwayland-server0
#   libx11-xcb1 libxaw7 libxcb-cursor0 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-present0 libxcb-randr0
#   libxcb-render-util0 libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1
#   libxcb-util1 libxcb-xfixes0 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomposite1 libxcursor1 libxdamage1 libxfixes3 libxft2 libxi6
#   libxinerama1 libxkbcommon-x11-0 libxkbfile1 libxmu6 libxrandr2 libxrender1
#   libxshmfence1 libxt6t64 libxtst6 libxv1 libxxf86dga1 libxxf86vm1
#   lto-disabled-list make mesa-vulkan-drivers nsight-compute-2024.3.2
#   nsight-systems-2024.5.1 openjdk-21-jre openjdk-21-jre-headless
#   session-migration ubuntu-mono x11-common x11-utils
# Suggested packages:
#   bzip2-doc debian-keyring g++-multilib g++-13-multilib gcc-13-doc alsa-utils
#   libasound2-plugins colord cups-common bzr gvfs liblcms2-utils pcscd
#   librsvg2-bin libstdc++-13-doc make-doc libnss-mdns fonts-ipafont-gothic
#   fonts-ipafont-mincho fonts-wqy-microhei | fonts-wqy-zenhei fonts-indic
#   mesa-utils
# Recommended packages:
#   luit
# The following NEW packages will be installed:
#   adwaita-icon-theme alsa-topology-conf alsa-ucm-conf at-spi2-common
#   at-spi2-core build-essential bzip2 ca-certificates-java cuda-cccl-12-6
#   cuda-command-line-tools-12-6 cuda-compiler-12-6 cuda-crt-12-6
#   cuda-cudart-12-6 cuda-cudart-dev-12-6 cuda-cuobjdump-12-6 cuda-cupti-12-6
#   cuda-cupti-dev-12-6 cuda-cuxxfilt-12-6 cuda-documentation-12-6
#   cuda-driver-dev-12-6 cuda-gdb-12-6 cuda-libraries-12-6
#   cuda-libraries-dev-12-6 cuda-nsight-12-6 cuda-nsight-compute-12-6
#   cuda-nsight-systems-12-6 cuda-nvcc-12-6 cuda-nvdisasm-12-6
#   cuda-nvml-dev-12-6 cuda-nvprof-12-6 cuda-nvprune-12-6 cuda-nvrtc-12-6
#   cuda-nvrtc-dev-12-6 cuda-nvtx-12-6 cuda-nvvm-12-6 cuda-nvvp-12-6
#   cuda-opencl-12-6 cuda-opencl-dev-12-6 cuda-profiler-api-12-6
#   cuda-sanitizer-12-6 cuda-toolkit cuda-toolkit-12-6
#   cuda-toolkit-12-6-config-common cuda-toolkit-12-config-common
#   cuda-toolkit-config-common cuda-tools-12-6 cuda-visual-tools-12-6
#   dconf-gsettings-backend dconf-service default-jre default-jre-headless
#   dpkg-dev fakeroot fontconfig fonts-dejavu-extra g++ g++-13
#   g++-13-x86-64-linux-gnu g++-x86-64-linux-gnu gds-tools-12-6
#   gsettings-desktop-schemas gtk-update-icon-cache hicolor-icon-theme
#   humanity-icon-theme java-common libalgorithm-diff-perl
#   libalgorithm-diff-xs-perl libalgorithm-merge-perl libasound2-data
#   libasound2t64 libatk-bridge2.0-0t64 libatk-wrapper-java
#   libatk-wrapper-java-jni libatk1.0-0t64 libatspi2.0-0t64 libavahi-client3
#   libavahi-common-data libavahi-common3 libcairo-gobject2 libcairo2 libcolord2
#   libcublas-12-6 libcublas-dev-12-6 libcufft-12-6 libcufft-dev-12-6
#   libcufile-12-6 libcufile-dev-12-6 libcups2t64 libcurand-12-6
#   libcurand-dev-12-6 libcusolver-12-6 libcusolver-dev-12-6 libcusparse-12-6
#   libcusparse-dev-12-6 libdatrie1 libdconf1 libdpkg-perl libdrm-amdgpu1
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libegl-mesa0 libegl1 libepoxy0
#   libfakeroot libfile-fcntllock-perl libgbm1 libgdk-pixbuf-2.0-0
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgif7 libgl1 libgl1-amber-dri
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgraphite2-3
#   libgtk-3-0t64 libgtk-3-bin libgtk-3-common libharfbuzz0b libice6 liblcms2-2
#   libllvm17t64 libnpp-12-6 libnpp-dev-12-6 libnvfatbin-12-6
#   libnvfatbin-dev-12-6 libnvjitlink-12-6 libnvjitlink-dev-12-6 libnvjpeg-12-6
#   libnvjpeg-dev-12-6 libopengl0 libpango-1.0-0 libpangocairo-1.0-0
#   libpangoft2-1.0-0 libpciaccess0 libpcsclite1 libpixman-1-0 librsvg2-2
#   librsvg2-common libsm6 libstdc++-13-dev libthai-data libthai0 libvulkan1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwayland-server0
#   libx11-xcb1 libxaw7 libxcb-cursor0 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-present0 libxcb-randr0
#   libxcb-render-util0 libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1
#   libxcb-util1 libxcb-xfixes0 libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1
#   libxcomposite1 libxcursor1 libxdamage1 libxfixes3 libxft2 libxi6
#   libxinerama1 libxkbcommon-x11-0 libxkbfile1 libxmu6 libxrandr2 libxrender1
#   libxshmfence1 libxt6t64 libxtst6 libxv1 libxxf86dga1 libxxf86vm1
#   lto-disabled-list make mesa-vulkan-drivers nsight-compute-2024.3.2
#   nsight-systems-2024.5.1 openjdk-21-jre openjdk-21-jre-headless
#   session-migration ubuntu-mono x11-common x11-utils
# 0 upgraded, 202 newly installed, 0 to remove and 32 not upgraded.
# Need to get 3103 MB of archives.
# After this operation, 7157 MB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgdk-pixbuf2.0-common all 2.42.10+dfsg-3ubuntu3.1 [8024 B]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgdk-pixbuf-2.0-0 amd64 2.42.10+dfsg-3ubuntu3.1 [147 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gtk-update-icon-cache amd64 3.24.41-4ubuntu1.2 [51.8 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 hicolor-icon-theme all 0.17-2 [9976 B]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 humanity-icon-theme all 0.6.16 [1282 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cccl-12-6 12.6.77-1 [974 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 ubuntu-mono all 24.04-0ubuntu1 [151 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 adwaita-icon-theme all 46.0-1 [723 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 alsa-topology-conf all 1.2.5.1-2 [15.5 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libasound2-data all 1.2.11-1build2 [21.0 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libasound2t64 amd64 1.2.11-1build2 [399 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 alsa-ucm-conf all 1.2.10-1ubuntu5.3 [64.2 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 at-spi2-common all 2.52.0-1build1 [8674 B]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxi6 amd64 2:1.8.1-1build1 [32.4 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libatspi2.0-0t64 amd64 2.52.0-1build1 [80.5 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 x11-common all 1:7.7+23ubuntu3 [21.7 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxtst6 amd64 2:1.2.3-1.1build1 [12.6 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libdconf1 amd64 0.40.0-4build2 [39.4 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 dconf-service amd64 0.40.0-4build2 [27.5 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 dconf-gsettings-backend amd64 0.40.0-4build2 [22.1 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 session-migration amd64 0.3.9build1 [9034 B]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gsettings-desktop-schemas all 46.1-0ubuntu1 [35.6 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 at-spi2-core amd64 2.52.0-1build1 [56.6 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libstdc++-13-dev amd64 13.3.0-6ubuntu2~24.04 [2420 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 g++-13-x86-64-linux-gnu amd64 13.3.0-6ubuntu2~24.04 [12.2 MB]
# Get:26 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cupti-12-6 12.6.80-1 [10.2 MB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 g++-13 amd64 13.3.0-6ubuntu2~24.04 [16.1 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 g++-x86-64-linux-gnu amd64 4:13.2.0-7ubuntu1 [964 B]
# Get:29 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 g++ amd64 4:13.2.0-7ubuntu1 [1100 B]
# Get:30 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 make amd64 4.3-4.1build2 [180 kB]
# Get:31 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libdpkg-perl all 1.22.6ubuntu6.1 [269 kB]
# Get:32 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bzip2 amd64 1.0.8-5.1build0.1 [34.5 kB]
# Get:33 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 lto-disabled-list all 47 [12.4 kB]
# Get:34 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 dpkg-dev all 1.22.6ubuntu6.1 [1074 kB]
# Get:35 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 build-essential amd64 12.10ubuntu1 [4928 B]
# Get:36 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 ca-certificates-java all 20240118 [11.6 kB]
# Get:37 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 java-common all 0.75+exp1 [6798 B]
# Get:38 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 liblcms2-2 amd64 2.14-2build1 [161 kB]
# Get:39 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libpcsclite1 amd64 2.0.3-1build1 [21.4 kB]
# Get:40 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 openjdk-21-jre-headless amd64 21.0.5+11-1ubuntu1~24.04 [46.4 MB]
# Get:41 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cupti-dev-12-6 12.6.80-1 [3927 kB]
# Get:42 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvdisasm-12-6 12.6.77-1 [49.9 MB]
# Get:43 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 default-jre-headless amd64 2:1.21-75+exp1 [3094 B]
# Get:44 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libatk1.0-0t64 amd64 2.52.0-1build1 [55.3 kB]
# Get:45 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libatk-bridge2.0-0t64 amd64 2.52.0-1build1 [66.0 kB]
# Get:46 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libpixman-1-0 amd64 0.42.2-1build1 [279 kB]
# Get:47 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-render0 amd64 1.15-1ubuntu2 [16.2 kB]
# Get:48 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-shm0 amd64 1.15-1ubuntu2 [5756 B]
# Get:49 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxrender1 amd64 1:0.9.10-1.1build1 [19.0 kB]
# Get:50 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libcairo2 amd64 1.18.0-3build1 [566 kB]
# Get:51 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libcairo-gobject2 amd64 1.18.0-3build1 [127 kB]
# Get:52 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libcolord2 amd64 1.4.7-1build2 [149 kB]
# Get:53 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libavahi-common-data amd64 0.8-13ubuntu6 [29.7 kB]
# Get:54 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libavahi-common3 amd64 0.8-13ubuntu6 [23.3 kB]
# Get:55 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libavahi-client3 amd64 0.8-13ubuntu6 [26.8 kB]
# Get:56 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcups2t64 amd64 2.4.7-1.2ubuntu7.3 [272 kB]
# Get:57 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libepoxy0 amd64 1.5.10-1build1 [220 kB]
# Get:58 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libgraphite2-3 amd64 1.3.14-2build1 [73.0 kB]
# Get:59 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libharfbuzz0b amd64 8.3.0-2build2 [469 kB]
# Get:60 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 fontconfig amd64 2.15.0-1.1ubuntu2 [180 kB]
# Get:61 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libthai-data all 0.1.29-2build1 [158 kB]
# Get:62 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libdatrie1 amd64 0.2.13-3build1 [19.0 kB]
# Get:63 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libthai0 amd64 0.1.29-2build1 [18.9 kB]
# Get:64 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libpango-1.0-0 amd64 1.52.1+ds-1build1 [231 kB]
# Get:65 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libpangoft2-1.0-0 amd64 1.52.1+ds-1build1 [42.5 kB]
# Get:66 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libpangocairo-1.0-0 amd64 1.52.1+ds-1build1 [28.8 kB]
# Get:67 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libwayland-client0 amd64 1.22.0-2.1build1 [26.4 kB]
# Get:68 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libwayland-cursor0 amd64 1.22.0-2.1build1 [10.4 kB]
# Get:69 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libwayland-egl1 amd64 1.22.0-2.1build1 [5628 B]
# Get:70 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcomposite1 amd64 1:0.4.5-1build3 [6320 B]
# Get:71 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxfixes3 amd64 1:6.0.0-2build1 [10.8 kB]
# Get:72 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcursor1 amd64 1:1.2.1-1build1 [20.7 kB]
# Get:73 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxdamage1 amd64 1:1.1.6-1build1 [6150 B]
# Get:74 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxinerama1 amd64 2:1.1.4-3build1 [6396 B]
# Get:75 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxrandr2 amd64 2:1.5.2-2build1 [19.7 kB]
# Get:76 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgtk-3-common all 3.24.41-4ubuntu1.2 [1202 kB]
# Get:77 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgtk-3-0t64 amd64 3.24.41-4ubuntu1.2 [2901 kB]
# Get:78 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cuobjdump-12-6 12.6.77-1 [221 kB]
# Get:79 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libglvnd0 amd64 1.7.0-1build1 [69.6 kB]
# Get:80 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libglapi-mesa amd64 24.0.9-0ubuntu0.3 [41.3 kB]
# Get:81 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libx11-xcb1 amd64 2:1.8.7-1build1 [7800 B]
# Get:82 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-dri2-0 amd64 1.15-1ubuntu2 [7222 B]
# Get:83 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-dri3-0 amd64 1.15-1ubuntu2 [7142 B]
# Get:84 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-glx0 amd64 1.15-1ubuntu2 [24.8 kB]
# Get:85 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-present0 amd64 1.15-1ubuntu2 [5676 B]
# Get:86 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-randr0 amd64 1.15-1ubuntu2 [17.9 kB]
# Get:87 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-gdb-12-6 12.6.77-1 [25.5 MB]
# Get:88 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-sync1 amd64 1.15-1ubuntu2 [9312 B]
# Get:89 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xfixes0 amd64 1.15-1ubuntu2 [10.2 kB]
# Get:90 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxshmfence1 amd64 1.3-1build5 [4764 B]
# Get:91 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxxf86vm1 amd64 1:1.1.4-1build4 [9282 B]
# Get:92 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libvulkan1 amd64 1.3.275.0-1build1 [142 kB]
# Get:93 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libdrm-amdgpu1 amd64 2.4.120-2build1 [20.2 kB]
# Get:94 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libpciaccess0 amd64 0.17-3build1 [18.6 kB]
# Get:95 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libdrm-intel1 amd64 2.4.120-2build1 [63.8 kB]
# Get:96 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libdrm-nouveau2 amd64 2.4.120-2build1 [17.7 kB]
# Get:97 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libdrm-radeon1 amd64 2.4.120-2build1 [20.8 kB]
# Get:98 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libllvm17t64 amd64 1:17.0.6-9ubuntu1 [26.2 MB]
# Get:99 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvprof-12-6 12.6.80-1 [2434 kB]
# Get:100 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvtx-12-6 12.6.77-1 [51.5 kB]
# Get:101 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgl1-mesa-dri amd64 24.0.9-0ubuntu0.3 [8950 kB]
# Get:102 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-sanitizer-12-6 12.6.77-1 [10.1 MB]
# Get:103 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libglx-mesa0 amd64 24.0.9-0ubuntu0.3 [154 kB]
# Get:104 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libglx0 amd64 1.7.0-1build1 [38.6 kB]
# Get:105 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libgl1 amd64 1.7.0-1build1 [102 kB]
# Get:106 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libgif7 amd64 5.2.2-1ubuntu1 [35.2 kB]
# Get:107 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 openjdk-21-jre amd64 21.0.5+11-1ubuntu1~24.04 [228 kB]
# Get:108 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 default-jre amd64 2:1.21-75+exp1 [922 B]
# Get:109 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xinerama0 amd64 1.15-1ubuntu2 [5410 B]
# Get:110 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build3 [10.8 kB]
# Get:111 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-util1 amd64 0.4.0-1build3 [10.7 kB]
# Get:112 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-image0 amd64 0.4.0-2build1 [10.8 kB]
# Get:113 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-keysyms1 amd64 0.4.0-1build4 [7956 B]
# Get:114 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-render-util0 amd64 0.3.9-1build4 [9608 B]
# Get:115 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-shape0 amd64 1.15-1ubuntu2 [6100 B]
# Get:116 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xkb1 amd64 1.15-1ubuntu2 [32.3 kB]
# Get:117 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxkbcommon-x11-0 amd64 1.6.0-1build1 [14.5 kB]
# Get:118 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxcb-xinput0 amd64 1.15-1ubuntu2 [33.2 kB]
# Get:119 http://nova.clouds.archive.ubuntu.com/ubuntu noble/universe amd64 libxcb-cursor0 amd64 0.1.4-1build1 [10.7 kB]
# Get:120 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libopengl0 amd64 1.7.0-1build1 [32.8 kB]
# Get:121 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-command-line-tools-12-6 12.6.3-1 [2546 B]
# Get:122 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libwayland-server0 amd64 1.22.0-2.1build1 [33.9 kB]
# Get:123 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgbm1 amd64 24.0.9-0ubuntu0.3 [42.8 kB]
# Get:124 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libegl-mesa0 amd64 24.0.9-0ubuntu0.3 [115 kB]
# Get:125 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libegl1 amd64 1.7.0-1build1 [28.7 kB]
# Get:126 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libfakeroot amd64 1.33-1 [32.4 kB]
# Get:127 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 fakeroot amd64 1.33-1 [67.2 kB]
# Get:128 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 fonts-dejavu-extra all 2.37-8 [1947 kB]
# Get:129 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cuxxfilt-12-6 12.6.77-1 [191 kB]
# Get:130 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libalgorithm-diff-perl all 1.201-1 [41.8 kB]
# Get:131 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libalgorithm-diff-xs-perl amd64 0.04-8build3 [11.2 kB]
# Get:132 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libalgorithm-merge-perl all 0.08-5 [11.4 kB]
# Get:133 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libice6 amd64 2:1.0.10-1build3 [41.4 kB]
# Get:134 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libsm6 amd64 2:1.2.3-1build3 [15.7 kB]
# Get:135 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxt6t64 amd64 1:1.2.1-1.2build1 [171 kB]
# Get:136 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-toolkit-config-common 12.6.77-1 [16.5 kB]
# Get:137 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxmu6 amd64 2:1.1.3-3build2 [47.6 kB]
# Get:138 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxaw7 amd64 2:1.0.14-1build2 [187 kB]
# Get:139 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxft2 amd64 2.3.6-1build1 [45.3 kB]
# Get:140 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxkbfile1 amd64 1:1.1.0-1build4 [70.0 kB]
# Get:141 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-toolkit-12-config-common 12.6.77-1 [16.5 kB]
# Get:142 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxv1 amd64 2:1.0.11-1.1build1 [10.7 kB]
# Get:143 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libxxf86dga1 amd64 2:1.1.5-1build1 [11.6 kB]
# Get:144 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 x11-utils amd64 7.7+6build2 [189 kB]
# Get:145 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libatk-wrapper-java all 0.40.0-3build2 [54.3 kB]
# Get:146 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libatk-wrapper-java-jni amd64 0.40.0-3build2 [46.4 kB]
# Get:147 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libfile-fcntllock-perl amd64 0.22-4ubuntu5 [30.7 kB]
# Get:148 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgdk-pixbuf2.0-bin amd64 2.42.10+dfsg-3ubuntu3.1 [13.9 kB]
# Get:149 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-toolkit-12-6-config-common 12.6.77-1 [16.5 kB]
# Get:150 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 libgl1-amber-dri amd64 21.3.9-0ubuntu2 [4212 kB]
# Get:151 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cudart-12-6 12.6.77-1 [166 kB]
# Get:152 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-driver-dev-12-6 12.6.77-1 [29.0 kB]
# Get:153 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgtk-3-bin amd64 3.24.41-4ubuntu1.2 [73.9 kB]
# Get:154 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 librsvg2-2 amd64 2.58.0+dfsg-1build1 [2135 kB]
# Get:155 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-cudart-dev-12-6 12.6.77-1 [1026 kB]
# Get:156 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 librsvg2-common amd64 2.58.0+dfsg-1build1 [11.8 kB]
# Get:157 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 mesa-vulkan-drivers amd64 24.0.9-0ubuntu0.3 [11.0 MB]
# Get:158 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvvm-12-6 12.6.85-1 [17.9 MB]
# Get:159 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-crt-12-6 12.6.85-1 [77.4 kB]
# Get:160 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvcc-12-6 12.6.85-1 [32.6 MB]
# Get:161 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvprune-12-6 12.6.77-1 [59.4 kB]
# Get:162 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-compiler-12-6 12.6.3-1 [2510 B]
# Get:163 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-documentation-12-6 12.6.77-1 [50.0 kB]
# Get:164 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvrtc-12-6 12.6.85-1 [17.0 MB]
# Get:165 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-opencl-12-6 12.6.77-1 [24.0 kB]
# Get:166 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcublas-12-6 12.6.4.1-1 [257 MB]
# Get:167 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcufft-12-6 11.3.0.4-1 [160 MB]
# Get:168 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcufile-12-6 1.11.1.6-1 [847 kB]
# Get:169 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcurand-12-6 10.3.7.77-1 [41.4 MB]
# Get:170 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcusolver-12-6 11.7.1.2-1 [97.2 MB]
# Get:171 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcusparse-12-6 12.5.4.2-1 [120 MB]
# Get:172 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnpp-12-6 12.3.1.54-1 [93.8 MB]
# Get:173 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnvjitlink-12-6 12.6.85-1 [14.7 MB]
# Get:174 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnvfatbin-12-6 12.6.77-1 [734 kB]
# Get:175 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnvjpeg-12-6 12.3.3.54-1 [2326 kB]
# Get:176 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-libraries-12-6 12.6.3-1 [2610 B]
# Get:177 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-profiler-api-12-6 12.6.77-1 [18.6 kB]
# Get:178 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvrtc-dev-12-6 12.6.85-1 [17.6 MB]
# Get:179 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-opencl-dev-12-6 12.6.77-1 [87.7 kB]
# Get:180 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcublas-dev-12-6 12.6.4.1-1 [277 MB]
# Get:181 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcufft-dev-12-6 11.3.0.4-1 [321 MB]
# Get:182 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcufile-dev-12-6 1.11.1.6-1 [2446 kB]
# Get:183 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcurand-dev-12-6 10.3.7.77-1 [41.7 MB]
# Get:184 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcusolver-dev-12-6 11.7.1.2-1 [66.7 MB]
# Get:185 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libcusparse-dev-12-6 12.5.4.2-1 [123 MB]
# Get:186 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnpp-dev-12-6 12.3.1.54-1 [92.4 MB]
# Get:187 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnvjitlink-dev-12-6 12.6.85-1 [14.6 MB]
# Get:188 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnvfatbin-dev-12-6 12.6.77-1 [607 kB]
# Get:189 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  libnvjpeg-dev-12-6 12.3.3.54-1 [2023 kB]
# Get:190 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-libraries-dev-12-6 12.6.3-1 [2654 B]
# Get:191 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nsight-12-6 12.6.77-1 [119 MB]
# Get:192 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  nsight-compute-2024.3.2 2024.3.2.3-1 [425 MB]
# Get:193 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nsight-compute-12-6 12.6.3-1 [4056 B]
# Get:194 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  nsight-systems-2024.5.1 2024.5.1.113-245134619542v0 [356 MB]
# Get:195 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nsight-systems-12-6 12.6.3-1 [3352 B]
# Get:196 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvml-dev-12-6 12.6.77-1 [148 kB]
# Get:197 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-nvvp-12-6 12.6.80-1 [115 MB]
# Get:198 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-visual-tools-12-6 12.6.3-1 [2946 B]
# Get:199 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  gds-tools-12-6 1.11.1.6-1 [39.0 MB]
# Get:200 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-tools-12-6 12.6.3-1 [2466 B]
# Get:201 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-toolkit-12-6 12.6.3-1 [3324 B]
# Get:202 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  cuda-toolkit 12.6.3-1 [2726 B]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 3103 MB in 2min 11s (23.6 MB/s)
# Selecting previously unselected package libgdk-pixbuf2.0-common.
# (Reading database ... 75354 files and directories currently installed.)
# Preparing to unpack .../000-libgdk-pixbuf2.0-common_2.42.10+dfsg-3ubuntu3.1_all.deb ...
# Unpacking libgdk-pixbuf2.0-common (2.42.10+dfsg-3ubuntu3.1) ...
# Selecting previously unselected package libgdk-pixbuf-2.0-0:amd64.
# Preparing to unpack .../001-libgdk-pixbuf-2.0-0_2.42.10+dfsg-3ubuntu3.1_amd64.deb ...
# Unpacking libgdk-pixbuf-2.0-0:amd64 (2.42.10+dfsg-3ubuntu3.1) ...
# Selecting previously unselected package gtk-update-icon-cache.
# Preparing to unpack .../002-gtk-update-icon-cache_3.24.41-4ubuntu1.2_amd64.deb ...
# Unpacking gtk-update-icon-cache (3.24.41-4ubuntu1.2) ...
# Selecting previously unselected package hicolor-icon-theme.
# Preparing to unpack .../003-hicolor-icon-theme_0.17-2_all.deb ...
# Unpacking hicolor-icon-theme (0.17-2) ...
# Selecting previously unselected package humanity-icon-theme.
# Preparing to unpack .../004-humanity-icon-theme_0.6.16_all.deb ...
# Unpacking humanity-icon-theme (0.6.16) ...
# Selecting previously unselected package ubuntu-mono.
# Preparing to unpack .../005-ubuntu-mono_24.04-0ubuntu1_all.deb ...
# Unpacking ubuntu-mono (24.04-0ubuntu1) ...
# Selecting previously unselected package adwaita-icon-theme.
# Preparing to unpack .../006-adwaita-icon-theme_46.0-1_all.deb ...
# Unpacking adwaita-icon-theme (46.0-1) ...
# Selecting previously unselected package alsa-topology-conf.
# Preparing to unpack .../007-alsa-topology-conf_1.2.5.1-2_all.deb ...
# Unpacking alsa-topology-conf (1.2.5.1-2) ...
# Selecting previously unselected package libasound2-data.
# Preparing to unpack .../008-libasound2-data_1.2.11-1build2_all.deb ...
# Unpacking libasound2-data (1.2.11-1build2) ...
# Selecting previously unselected package libasound2t64:amd64.
# Preparing to unpack .../009-libasound2t64_1.2.11-1build2_amd64.deb ...
# Unpacking libasound2t64:amd64 (1.2.11-1build2) ...
# Selecting previously unselected package alsa-ucm-conf.
# Preparing to unpack .../010-alsa-ucm-conf_1.2.10-1ubuntu5.3_all.deb ...
# Unpacking alsa-ucm-conf (1.2.10-1ubuntu5.3) ...
# Selecting previously unselected package at-spi2-common.
# Preparing to unpack .../011-at-spi2-common_2.52.0-1build1_all.deb ...
# Unpacking at-spi2-common (2.52.0-1build1) ...
# Selecting previously unselected package libxi6:amd64.
# Preparing to unpack .../012-libxi6_2%3a1.8.1-1build1_amd64.deb ...
# Unpacking libxi6:amd64 (2:1.8.1-1build1) ...
# Selecting previously unselected package libatspi2.0-0t64:amd64.
# Preparing to unpack .../013-libatspi2.0-0t64_2.52.0-1build1_amd64.deb ...
# Unpacking libatspi2.0-0t64:amd64 (2.52.0-1build1) ...
# Selecting previously unselected package x11-common.
# Preparing to unpack .../014-x11-common_1%3a7.7+23ubuntu3_all.deb ...
# Unpacking x11-common (1:7.7+23ubuntu3) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../015-libxtst6_2%3a1.2.3-1.1build1_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1.1build1) ...
# Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../016-libdconf1_0.40.0-4build2_amd64.deb ...
# Unpacking libdconf1:amd64 (0.40.0-4build2) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../017-dconf-service_0.40.0-4build2_amd64.deb ...
# Unpacking dconf-service (0.40.0-4build2) ...
# Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../018-dconf-gsettings-backend_0.40.0-4build2_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.40.0-4build2) ...
# Selecting previously unselected package session-migration.
# Preparing to unpack .../019-session-migration_0.3.9build1_amd64.deb ...
# Unpacking session-migration (0.3.9build1) ...
# Selecting previously unselected package gsettings-desktop-schemas.
# Preparing to unpack .../020-gsettings-desktop-schemas_46.1-0ubuntu1_all.deb ...
# Unpacking gsettings-desktop-schemas (46.1-0ubuntu1) ...
# Selecting previously unselected package at-spi2-core.
# Preparing to unpack .../021-at-spi2-core_2.52.0-1build1_amd64.deb ...
# Unpacking at-spi2-core (2.52.0-1build1) ...
# Selecting previously unselected package libstdc++-13-dev:amd64.
# Preparing to unpack .../022-libstdc++-13-dev_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking libstdc++-13-dev:amd64 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package g++-13-x86-64-linux-gnu.
# Preparing to unpack .../023-g++-13-x86-64-linux-gnu_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking g++-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package g++-13.
# Preparing to unpack .../024-g++-13_13.3.0-6ubuntu2~24.04_amd64.deb ...
# Unpacking g++-13 (13.3.0-6ubuntu2~24.04) ...
# Selecting previously unselected package g++-x86-64-linux-gnu.
# Preparing to unpack .../025-g++-x86-64-linux-gnu_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking g++-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package g++.
# Preparing to unpack .../026-g++_4%3a13.2.0-7ubuntu1_amd64.deb ...
# Unpacking g++ (4:13.2.0-7ubuntu1) ...
# Selecting previously unselected package make.
# Preparing to unpack .../027-make_4.3-4.1build2_amd64.deb ...
# Unpacking make (4.3-4.1build2) ...
# Selecting previously unselected package libdpkg-perl.
# Preparing to unpack .../028-libdpkg-perl_1.22.6ubuntu6.1_all.deb ...
# Unpacking libdpkg-perl (1.22.6ubuntu6.1) ...
# Selecting previously unselected package bzip2.
# Preparing to unpack .../029-bzip2_1.0.8-5.1build0.1_amd64.deb ...
# Unpacking bzip2 (1.0.8-5.1build0.1) ...
# Selecting previously unselected package lto-disabled-list.
# Preparing to unpack .../030-lto-disabled-list_47_all.deb ...
# Unpacking lto-disabled-list (47) ...
# Selecting previously unselected package dpkg-dev.
# Preparing to unpack .../031-dpkg-dev_1.22.6ubuntu6.1_all.deb ...
# Unpacking dpkg-dev (1.22.6ubuntu6.1) ...
# Selecting previously unselected package build-essential.
# Preparing to unpack .../032-build-essential_12.10ubuntu1_amd64.deb ...
# Unpacking build-essential (12.10ubuntu1) ...
# Selecting previously unselected package ca-certificates-java.
# Preparing to unpack .../033-ca-certificates-java_20240118_all.deb ...
# Unpacking ca-certificates-java (20240118) ...
# Selecting previously unselected package cuda-cccl-12-6.
# Preparing to unpack .../034-cuda-cccl-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cccl-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-cupti-12-6.
# Preparing to unpack .../035-cuda-cupti-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-cupti-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-6.
# Preparing to unpack .../036-cuda-cupti-dev-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-6.
# Preparing to unpack .../037-cuda-nvdisasm-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-6.
# Preparing to unpack .../038-cuda-cuobjdump-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-gdb-12-6.
# Preparing to unpack .../039-cuda-gdb-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-gdb-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvprof-12-6.
# Preparing to unpack .../040-cuda-nvprof-12-6_12.6.80-1_amd64.deb ...
# Unpacking cuda-nvprof-12-6 (12.6.80-1) ...
# Selecting previously unselected package cuda-nvtx-12-6.
# Preparing to unpack .../041-cuda-nvtx-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvtx-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-sanitizer-12-6.
# Preparing to unpack .../042-cuda-sanitizer-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-6.
# Preparing to unpack .../043-cuda-command-line-tools-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-6.
# Preparing to unpack .../044-cuda-cuxxfilt-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-toolkit-config-common.
# Preparing to unpack .../045-cuda-toolkit-config-common_12.6.77-1_all.deb ...
# Unpacking cuda-toolkit-config-common (12.6.77-1) ...
# Selecting previously unselected package cuda-toolkit-12-config-common.
# Preparing to unpack .../046-cuda-toolkit-12-config-common_12.6.77-1_all.deb ...
# Unpacking cuda-toolkit-12-config-common (12.6.77-1) ...
# Selecting previously unselected package cuda-toolkit-12-6-config-common.
# Preparing to unpack .../047-cuda-toolkit-12-6-config-common_12.6.77-1_all.deb ...
# Unpacking cuda-toolkit-12-6-config-common (12.6.77-1) ...
# Selecting previously unselected package cuda-cudart-12-6.
# Preparing to unpack .../048-cuda-cudart-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cudart-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-driver-dev-12-6.
# Preparing to unpack .../049-cuda-driver-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-6.
# Preparing to unpack .../050-cuda-cudart-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvvm-12-6.
# Preparing to unpack .../051-cuda-nvvm-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvvm-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-crt-12-6.
# Preparing to unpack .../052-cuda-crt-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-crt-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-nvcc-12-6.
# Preparing to unpack .../053-cuda-nvcc-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvcc-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-nvprune-12-6.
# Preparing to unpack .../054-cuda-nvprune-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-nvprune-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-compiler-12-6.
# Preparing to unpack .../055-cuda-compiler-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-compiler-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-documentation-12-6.
# Preparing to unpack .../056-cuda-documentation-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-documentation-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvrtc-12-6.
# Preparing to unpack .../057-cuda-nvrtc-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-opencl-12-6.
# Preparing to unpack .../058-cuda-opencl-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-opencl-12-6 (12.6.77-1) ...
# Selecting previously unselected package libcublas-12-6.
# Preparing to unpack .../059-libcublas-12-6_12.6.4.1-1_amd64.deb ...
# Unpacking libcublas-12-6 (12.6.4.1-1) ...
# Selecting previously unselected package libcufft-12-6.
# Preparing to unpack .../060-libcufft-12-6_11.3.0.4-1_amd64.deb ...
# Unpacking libcufft-12-6 (11.3.0.4-1) ...
# Selecting previously unselected package libcufile-12-6.
# Preparing to unpack .../061-libcufile-12-6_1.11.1.6-1_amd64.deb ...
# Unpacking libcufile-12-6 (1.11.1.6-1) ...
# Selecting previously unselected package libcurand-12-6.
# Preparing to unpack .../062-libcurand-12-6_10.3.7.77-1_amd64.deb ...
# Unpacking libcurand-12-6 (10.3.7.77-1) ...
# Selecting previously unselected package libcusolver-12-6.
# Preparing to unpack .../063-libcusolver-12-6_11.7.1.2-1_amd64.deb ...
# Unpacking libcusolver-12-6 (11.7.1.2-1) ...
# Selecting previously unselected package libcusparse-12-6.
# Preparing to unpack .../064-libcusparse-12-6_12.5.4.2-1_amd64.deb ...
# Unpacking libcusparse-12-6 (12.5.4.2-1) ...
# Selecting previously unselected package libnpp-12-6.
# Preparing to unpack .../065-libnpp-12-6_12.3.1.54-1_amd64.deb ...
# Unpacking libnpp-12-6 (12.3.1.54-1) ...
# Selecting previously unselected package libnvjitlink-12-6.
# Preparing to unpack .../066-libnvjitlink-12-6_12.6.85-1_amd64.deb ...
# Unpacking libnvjitlink-12-6 (12.6.85-1) ...
# Selecting previously unselected package libnvfatbin-12-6.
# Preparing to unpack .../067-libnvfatbin-12-6_12.6.77-1_amd64.deb ...
# Unpacking libnvfatbin-12-6 (12.6.77-1) ...
# Selecting previously unselected package libnvjpeg-12-6.
# Preparing to unpack .../068-libnvjpeg-12-6_12.3.3.54-1_amd64.deb ...
# Unpacking libnvjpeg-12-6 (12.3.3.54-1) ...
# Selecting previously unselected package cuda-libraries-12-6.
# Preparing to unpack .../069-cuda-libraries-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-libraries-12-6 (12.6.3-1) ...
# Selecting previously unselected package cuda-profiler-api-12-6.
# Preparing to unpack .../070-cuda-profiler-api-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-6 (12.6.77-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-6.
# Preparing to unpack .../071-cuda-nvrtc-dev-12-6_12.6.85-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-6 (12.6.85-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-6.
# Preparing to unpack .../072-cuda-opencl-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package libcublas-dev-12-6.
# Preparing to unpack .../073-libcublas-dev-12-6_12.6.4.1-1_amd64.deb ...
# Unpacking libcublas-dev-12-6 (12.6.4.1-1) ...
# Selecting previously unselected package libcufft-dev-12-6.
# Preparing to unpack .../074-libcufft-dev-12-6_11.3.0.4-1_amd64.deb ...
# Unpacking libcufft-dev-12-6 (11.3.0.4-1) ...
# Selecting previously unselected package libcufile-dev-12-6.
# Preparing to unpack .../075-libcufile-dev-12-6_1.11.1.6-1_amd64.deb ...
# Unpacking libcufile-dev-12-6 (1.11.1.6-1) ...
# Selecting previously unselected package libcurand-dev-12-6.
# Preparing to unpack .../076-libcurand-dev-12-6_10.3.7.77-1_amd64.deb ...
# Unpacking libcurand-dev-12-6 (10.3.7.77-1) ...
# Selecting previously unselected package libcusolver-dev-12-6.
# Preparing to unpack .../077-libcusolver-dev-12-6_11.7.1.2-1_amd64.deb ...
# Unpacking libcusolver-dev-12-6 (11.7.1.2-1) ...
# Selecting previously unselected package libcusparse-dev-12-6.
# Preparing to unpack .../078-libcusparse-dev-12-6_12.5.4.2-1_amd64.deb ...
# Unpacking libcusparse-dev-12-6 (12.5.4.2-1) ...
# Selecting previously unselected package libnpp-dev-12-6.
# Preparing to unpack .../079-libnpp-dev-12-6_12.3.1.54-1_amd64.deb ...
# Unpacking libnpp-dev-12-6 (12.3.1.54-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-6.
# Preparing to unpack .../080-libnvjitlink-dev-12-6_12.6.85-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-6 (12.6.85-1) ...
# Selecting previously unselected package libnvfatbin-dev-12-6.
# Preparing to unpack .../081-libnvfatbin-dev-12-6_12.6.77-1_amd64.deb ...
# Unpacking libnvfatbin-dev-12-6 (12.6.77-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-6.
# Preparing to unpack .../082-libnvjpeg-dev-12-6_12.3.3.54-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-6 (12.3.3.54-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-6.
# Preparing to unpack .../083-cuda-libraries-dev-12-6_12.6.3-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-6 (12.6.3-1) ...
# Selecting previously unselected package java-common.
# Preparing to unpack .../084-java-common_0.75+exp1_all.deb ...
# Unpacking java-common (0.75+exp1) ...
# Selecting previously unselected package liblcms2-2:amd64.
# Preparing to unpack .../085-liblcms2-2_2.14-2build1_amd64.deb ...
# Unpacking liblcms2-2:amd64 (2.14-2build1) ...
# Selecting previously unselected package libpcsclite1:amd64.
# ...
# Setting up libatspi2.0-0t64:amd64 (2.52.0-1build1) ...
# Setting up cuda-nvprune-12-6 (12.6.77-1) ...
# Setting up libxinerama1:amd64 (2:1.1.4-3build1) ...
# Setting up libxkbcommon-x11-0:amd64 (1.6.0-1build1) ...
# Setting up libxv1:amd64 (2:1.0.11-1.1build1) ...
# Setting up cuda-driver-dev-12-6 (12.6.77-1) ...
# Setting up cuda-nsight-compute-12-6 (12.6.3-1) ...
# Setting up libxrandr2:amd64 (2:1.5.2-2build1) ...
# Setting up libpcsclite1:amd64 (2.0.3-1build1) ...
# Setting up libglapi-mesa:amd64 (24.0.9-0ubuntu0.3) ...
# Setting up libdpkg-perl (1.22.6ubuntu6.1) ...
# Setting up libvulkan1:amd64 (1.3.275.0-1build1) ...
# Setting up libxcb-dri2-0:amd64 (1.15-1ubuntu2) ...
# Setting up libgif7:amd64 (5.2.2-1ubuntu1) ...
# Setting up fonts-dejavu-extra (2.37-8) ...
# Setting up alsa-topology-conf (1.2.5.1-2) ...
# Setting up libxshmfence1:amd64 (1.3-1build5) ...
# Setting up cuda-toolkit-12-6-config-common (12.6.77-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.6 to provide /usr/local/cuda (cuda) in auto mode
# update-alternatives: using /usr/local/cuda-12.6 to provide /usr/local/cuda-12 (cuda-12) in auto mode
# Setting up at-spi2-common (2.52.0-1build1) ...
# Setting up libxcb-randr0:amd64 (1.15-1ubuntu2) ...
# Setting up cuda-cuobjdump-12-6 (12.6.77-1) ...
# Setting up cuda-nvrtc-12-6 (12.6.85-1) ...
# Setting up libharfbuzz0b:amd64 (8.3.0-2build2) ...
# Setting up cuda-sanitizer-12-6 (12.6.77-1) ...
# Setting up libthai-data (0.1.29-2build1) ...
# Setting up libgdk-pixbuf-2.0-0:amd64 (2.42.10+dfsg-3ubuntu3.1) ...
# Setting up libcairo-gobject2:amd64 (1.18.0-3build1) ...
# Setting up libwayland-egl1:amd64 (1.22.0-2.1build1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build4) ...
# Setting up ca-certificates-java (20240118) ...
# No JRE found. Skipping Java certificates setup.
# Setting up cuda-cupti-12-6 (12.6.80-1) ...
# Setting up cuda-nvprof-12-6 (12.6.80-1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build3) ...
# Setting up libalgorithm-diff-xs-perl:amd64 (0.04-8build3) ...
# Setting up cuda-toolkit-12-config-common (12.6.77-1) ...
# Setting up libstdc++-13-dev:amd64 (13.3.0-6ubuntu2~24.04) ...
# Setting up libalgorithm-merge-perl (0.08-5) ...
# Setting up libcusolver-12-6 (11.7.1.2-1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.120-2build1) ...
# Setting up libwayland-client0:amd64 (1.22.0-2.1build1) ...
# Setting up libgl1-amber-dri:amd64 (21.3.9-0ubuntu2) ...
# Setting up mesa-vulkan-drivers:amd64 (24.0.9-0ubuntu0.3) ...
# Setting up gtk-update-icon-cache (3.24.41-4ubuntu1.2) ...
# Setting up libice6:amd64 (2:1.0.10-1build3) ...
# Setting up libnvjitlink-12-6 (12.6.85-1) ...
# Setting up libxft2:amd64 (2.3.6-1build1) ...
# Setting up libcurand-12-6 (10.3.7.77-1) ...
# Setting up libatk1.0-0t64:amd64 (2.52.0-1build1) ...
# Setting up libcufft-12-6 (11.3.0.4-1) ...
# Setting up openjdk-21-jre-headless:amd64 (21.0.5+11-1ubuntu1~24.04) ...
# update-alternatives: using /usr/lib/jvm/java-21-openjdk-amd64/bin/java to provide /usr/bin/java (java) in auto mode
# update-alternatives: using /usr/lib/jvm/java-21-openjdk-amd64/bin/jpackage to provide /usr/bin/jpackage (jpackage) in auto mode
# update-alternatives: using /usr/lib/jvm/java-21-openjdk-amd64/bin/keytool to provide /usr/bin/keytool (keytool) in auto mode
# update-alternatives: using /usr/lib/jvm/java-21-openjdk-amd64/bin/rmiregistry to provide /usr/bin/rmiregistry (rmiregistry) in auto mode
# update-alternatives: using /usr/lib/jvm/java-21-openjdk-amd64/lib/jexec to provide /usr/bin/jexec (jexec) in auto mode
# Setting up g++-13-x86-64-linux-gnu (13.3.0-6ubuntu2~24.04) ...
# Setting up libcufft-dev-12-6 (11.3.0.4-1) ...
# Setting up libnpp-12-6 (12.3.1.54-1) ...
# Setting up libnvjitlink-dev-12-6 (12.6.85-1) ...
# Setting up libgbm1:amd64 (24.0.9-0ubuntu0.3) ...
# Setting up alsa-ucm-conf (1.2.10-1ubuntu5.3) ...
# Setting up libxtst6:amd64 (2:1.2.3-1.1build1) ...
# Setting up libcusparse-12-6 (12.5.4.2-1) ...
# Setting up libxcursor1:amd64 (1:1.2.1-1build1) ...
# Setting up libgl1-mesa-dri:amd64 (24.0.9-0ubuntu0.3) ...
# Setting up libavahi-common3:amd64 (0.8-13ubuntu6) ...
# Setting up cuda-cupti-dev-12-6 (12.6.80-1) ...
# Setting up dconf-service (0.40.0-4build2) ...
# Setting up libnvfatbin-12-6 (12.6.77-1) ...
# Setting up libcurand-dev-12-6 (10.3.7.77-1) ...
# Setting up dpkg-dev (1.22.6ubuntu6.1) ...
# Setting up libnpp-dev-12-6 (12.3.1.54-1) ...
# Setting up libcublas-12-6 (12.6.4.1-1) ...
# Setting up libthai0:amd64 (0.1.29-2build1) ...
# Setting up libegl-mesa0:amd64 (24.0.9-0ubuntu0.3) ...
# Setting up libcublas-dev-12-6 (12.6.4.1-1) ...
# Setting up cuda-cudart-12-6 (12.6.77-1) ...
# Setting up cuda-gdb-12-6 (12.6.77-1) ...
# Setting up libnvjpeg-12-6 (12.3.3.54-1) ...
# Setting up libcufile-12-6 (1.11.1.6-1) ...
# Setting alternatives
# update-alternatives: using /usr/local/cuda-12.6/gds/cufile.json to provide /etc/cufile.json (cufile.json) in auto mode
# Setting up cuda-opencl-12-6 (12.6.77-1) ...
# Setting up libcusparse-dev-12-6 (12.5.4.2-1) ...
# Setting up cuda-libraries-12-6 (12.6.3-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.42.10+dfsg-3ubuntu3.1) ...
# Setting up libwayland-cursor0:amd64 (1.22.0-2.1build1) ...
# Setting up cuda-nvrtc-dev-12-6 (12.6.85-1) ...
# Setting up libegl1:amd64 (1.7.0-1build1) ...
# Setting up g++-x86-64-linux-gnu (4:13.2.0-7ubuntu1) ...
# Setting up libcusolver-dev-12-6 (11.7.1.2-1) ...
# Setting up cuda-command-line-tools-12-6 (12.6.3-1) ...
# Setting up libsm6:amd64 (2:1.2.3-1build3) ...
# Setting up cuda-opencl-dev-12-6 (12.6.77-1) ...
# Setting up libavahi-client3:amd64 (0.8-13ubuntu6) ...
# Setting up libatk-bridge2.0-0t64:amd64 (2.52.0-1build1) ...
# Setting up g++-13 (13.3.0-6ubuntu2~24.04) ...
# Setting up libglx-mesa0:amd64 (24.0.9-0ubuntu0.3) ...
# Setting up libglx0:amd64 (1.7.0-1build1) ...
# Setting up dconf-gsettings-backend:amd64 (0.40.0-4build2) ...
# Setting up nsight-systems-2024.5.1 (2024.5.1.113-245134619542v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2024.5.1/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Setting up libnvfatbin-dev-12-6 (12.6.77-1) ...
# Setting up libnvjpeg-dev-12-6 (12.3.3.54-1) ...
# Setting up libpango-1.0-0:amd64 (1.52.1+ds-1build1) ...
# Setting up libcufile-dev-12-6 (1.11.1.6-1) ...
# Setting up cuda-cudart-dev-12-6 (12.6.77-1) ...
# Setting up cuda-libraries-dev-12-6 (12.6.3-1) ...
# Setting up libgl1:amd64 (1.7.0-1build1) ...
# Setting up libxt6t64:amd64 (1:1.2.1-1.2build1) ...
# Setting up g++ (4:13.2.0-7ubuntu1) ...
# update-alternatives: using /usr/bin/g++ to provide /usr/bin/c++ (c++) in auto mode
# Setting up cuda-nsight-systems-12-6 (12.6.3-1) ...
# Setting up build-essential (12.10ubuntu1) ...
# Setting up libpangoft2-1.0-0:amd64 (1.52.1+ds-1build1) ...
# Setting up libcups2t64:amd64 (2.4.7-1.2ubuntu7.3) ...
# Setting up libgtk-3-common (3.24.41-4ubuntu1.2) ...
# Setting up libpangocairo-1.0-0:amd64 (1.52.1+ds-1build1) ...
# Setting up gsettings-desktop-schemas (46.1-0ubuntu1) ...
# Setting up libxmu6:amd64 (2:1.1.3-3build2) ...
# Setting up cuda-crt-12-6 (12.6.85-1) ...
# Setting up cuda-nvvm-12-6 (12.6.85-1) ...
# Setting up libxaw7:amd64 (2:1.0.14-1build2) ...
# Setting up librsvg2-2:amd64 (2.58.0+dfsg-1build1) ...
# Setting up librsvg2-common:amd64 (2.58.0+dfsg-1build1) ...
# Setting up x11-utils (7.7+6build2) ...
# Setting up cuda-nvcc-12-6 (12.6.85-1) ...
# Setting up libatk-wrapper-java (0.40.0-3build2) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.40.0-3build2) ...
# Setting up cuda-compiler-12-6 (12.6.3-1) ...
# Setting up adwaita-icon-theme (46.0-1) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up humanity-icon-theme (0.6.16) ...
# Setting up ubuntu-mono (24.04-0ubuntu1) ...
# Processing triggers for man-db (2.12.0-4build2) ...
# Processing triggers for libglib2.0-0t64:amd64 (2.80.0-6ubuntu3.2) ...
# Setting up libgtk-3-0t64:amd64 (3.24.41-4ubuntu1.2) ...
# Setting up at-spi2-core (2.52.0-1build1) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.3) ...
# Setting up libgtk-3-bin (3.24.41-4ubuntu1.2) ...
# Processing triggers for ca-certificates-java (20240118) ...
# Adding debian:ACCVRAIZ1.pem
# Adding debian:AC_RAIZ_FNMT-RCM.pem
# Adding debian:AC_RAIZ_FNMT-RCM_SERVIDORES_SEGUROS.pem
# Adding debian:ANF_Secure_Server_Root_CA.pem
# Adding debian:Actalis_Authentication_Root_CA.pem
# Adding debian:AffirmTrust_Commercial.pem
# Adding debian:AffirmTrust_Networking.pem
# Adding debian:AffirmTrust_Premium.pem
# Adding debian:AffirmTrust_Premium_ECC.pem
# Adding debian:Amazon_Root_CA_1.pem
# Adding debian:Amazon_Root_CA_2.pem
# Adding debian:Amazon_Root_CA_3.pem
# Adding debian:Amazon_Root_CA_4.pem
# Adding debian:Atos_TrustedRoot_2011.pem
# Adding debian:Atos_TrustedRoot_Root_CA_ECC_TLS_2021.pem
# Adding debian:Atos_TrustedRoot_Root_CA_RSA_TLS_2021.pem
# Adding debian:Autoridad_de_Certificacion_Firmaprofesional_CIF_A62634068.pem
# Adding debian:BJCA_Global_Root_CA1.pem
# Adding debian:BJCA_Global_Root_CA2.pem
# Adding debian:Baltimore_CyberTrust_Root.pem
# Adding debian:Buypass_Class_2_Root_CA.pem
# Adding debian:Buypass_Class_3_Root_CA.pem
# Adding debian:CA_Disig_Root_R2.pem
# Adding debian:CFCA_EV_ROOT.pem
# Adding debian:COMODO_Certification_Authority.pem
# Adding debian:COMODO_ECC_Certification_Authority.pem
# Adding debian:COMODO_RSA_Certification_Authority.pem
# Adding debian:Certainly_Root_E1.pem
# Adding debian:Certainly_Root_R1.pem
# Adding debian:Certigna.pem
# Adding debian:Certigna_Root_CA.pem
# Adding debian:Certum_EC-384_CA.pem
# Adding debian:Certum_Trusted_Network_CA.pem
# Adding debian:Certum_Trusted_Network_CA_2.pem
# Adding debian:Certum_Trusted_Root_CA.pem
# Adding debian:CommScope_Public_Trust_ECC_Root-01.pem
# Adding debian:CommScope_Public_Trust_ECC_Root-02.pem
# Adding debian:CommScope_Public_Trust_RSA_Root-01.pem
# Adding debian:CommScope_Public_Trust_RSA_Root-02.pem
# Adding debian:Comodo_AAA_Services_root.pem
# Adding debian:D-TRUST_BR_Root_CA_1_2020.pem
# Adding debian:D-TRUST_EV_Root_CA_1_2020.pem
# Adding debian:D-TRUST_Root_Class_3_CA_2_2009.pem
# Adding debian:D-TRUST_Root_Class_3_CA_2_EV_2009.pem
# Adding debian:DigiCert_Assured_ID_Root_CA.pem
# Adding debian:DigiCert_Assured_ID_Root_G2.pem
# Adding debian:DigiCert_Assured_ID_Root_G3.pem
# Adding debian:DigiCert_Global_Root_CA.pem
# Adding debian:DigiCert_Global_Root_G2.pem
# Adding debian:DigiCert_Global_Root_G3.pem
# Adding debian:DigiCert_High_Assurance_EV_Root_CA.pem
# Adding debian:DigiCert_TLS_ECC_P384_Root_G5.pem
# Adding debian:DigiCert_TLS_RSA4096_Root_G5.pem
# Adding debian:DigiCert_Trusted_Root_G4.pem
# Adding debian:Entrust.net_Premium_2048_Secure_Server_CA.pem
# Adding debian:Entrust_Root_Certification_Authority.pem
# Adding debian:Entrust_Root_Certification_Authority_-_EC1.pem
# Adding debian:Entrust_Root_Certification_Authority_-_G2.pem
# Adding debian:Entrust_Root_Certification_Authority_-_G4.pem
# Adding debian:GDCA_TrustAUTH_R5_ROOT.pem
# Adding debian:GLOBALTRUST_2020.pem
# Adding debian:GTS_Root_R1.pem
# Adding debian:GTS_Root_R2.pem
# Adding debian:GTS_Root_R3.pem
# Adding debian:GTS_Root_R4.pem
# Adding debian:GlobalSign_ECC_Root_CA_-_R4.pem
# Adding debian:GlobalSign_ECC_Root_CA_-_R5.pem
# Adding debian:GlobalSign_Root_CA.pem
# Adding debian:GlobalSign_Root_CA_-_R3.pem
# Adding debian:GlobalSign_Root_CA_-_R6.pem
# Adding debian:GlobalSign_Root_E46.pem
# Adding debian:GlobalSign_Root_R46.pem
# Adding debian:Go_Daddy_Class_2_CA.pem
# Adding debian:Go_Daddy_Root_Certificate_Authority_-_G2.pem
# Adding debian:HARICA_TLS_ECC_Root_CA_2021.pem
# Adding debian:HARICA_TLS_RSA_Root_CA_2021.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_ECC_RootCA_2015.pem
# Adding debian:Hellenic_Academic_and_Research_Institutions_RootCA_2015.pem
# Adding debian:HiPKI_Root_CA_-_G1.pem
# Adding debian:Hongkong_Post_Root_CA_3.pem
# Adding debian:ISRG_Root_X1.pem
# Adding debian:ISRG_Root_X2.pem
# Adding debian:IdenTrust_Commercial_Root_CA_1.pem
# Adding debian:IdenTrust_Public_Sector_Root_CA_1.pem
# Adding debian:Izenpe.com.pem
# Adding debian:Microsec_e-Szigno_Root_CA_2009.pem
# Adding debian:Microsoft_ECC_Root_Certificate_Authority_2017.pem
# Adding debian:Microsoft_RSA_Root_Certificate_Authority_2017.pem
# Adding debian:NAVER_Global_Root_Certification_Authority.pem
# Adding debian:NetLock_Arany_=Class_Gold=_Főtanúsítvány.pem
# Adding debian:OISTE_WISeKey_Global_Root_GB_CA.pem
# Adding debian:OISTE_WISeKey_Global_Root_GC_CA.pem
# Adding debian:QuoVadis_Root_CA_1_G3.pem
# Adding debian:QuoVadis_Root_CA_2.pem
# Adding debian:QuoVadis_Root_CA_2_G3.pem
# Adding debian:QuoVadis_Root_CA_3.pem
# Adding debian:QuoVadis_Root_CA_3_G3.pem
# Adding debian:SSL.com_EV_Root_Certification_Authority_ECC.pem
# Adding debian:SSL.com_EV_Root_Certification_Authority_RSA_R2.pem
# Adding debian:SSL.com_Root_Certification_Authority_ECC.pem
# Adding debian:SSL.com_Root_Certification_Authority_RSA.pem
# Adding debian:SSL.com_TLS_ECC_Root_CA_2022.pem
# Adding debian:SSL.com_TLS_RSA_Root_CA_2022.pem
# Adding debian:SZAFIR_ROOT_CA2.pem
# Adding debian:Sectigo_Public_Server_Authentication_Root_E46.pem
# Adding debian:Sectigo_Public_Server_Authentication_Root_R46.pem
# Adding debian:SecureSign_RootCA11.pem
# Adding debian:SecureTrust_CA.pem
# Adding debian:Secure_Global_CA.pem
# Adding debian:Security_Communication_ECC_RootCA1.pem
# Adding debian:Security_Communication_RootCA2.pem
# Adding debian:Security_Communication_RootCA3.pem
# Adding debian:Security_Communication_Root_CA.pem
# Adding debian:Starfield_Class_2_CA.pem
# Adding debian:Starfield_Root_Certificate_Authority_-_G2.pem
# Adding debian:Starfield_Services_Root_Certificate_Authority_-_G2.pem
# Adding debian:SwissSign_Gold_CA_-_G2.pem
# Adding debian:SwissSign_Silver_CA_-_G2.pem
# Adding debian:T-TeleSec_GlobalRoot_Class_2.pem
# Adding debian:T-TeleSec_GlobalRoot_Class_3.pem
# Adding debian:TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1.pem
# Adding debian:TWCA_Global_Root_CA.pem
# Adding debian:TWCA_Root_Certification_Authority.pem
# Adding debian:TeliaSonera_Root_CA_v1.pem
# Adding debian:Telia_Root_CA_v2.pem
# Adding debian:TrustAsia_Global_Root_CA_G3.pem
# Adding debian:TrustAsia_Global_Root_CA_G4.pem
# Adding debian:Trustwave_Global_Certification_Authority.pem
# Adding debian:Trustwave_Global_ECC_P256_Certification_Authority.pem
# Adding debian:Trustwave_Global_ECC_P384_Certification_Authority.pem
# Adding debian:TunTrust_Root_CA.pem
# Adding debian:UCA_Extended_Validation_Root.pem
# Adding debian:UCA_Global_G2_Root.pem
# Adding debian:USERTrust_ECC_Certification_Authority.pem
# Adding debian:USERTrust_RSA_Certification_Authority.pem
# Adding debian:XRamp_Global_CA_Root.pem
# Adding debian:certSIGN_ROOT_CA.pem
# Adding debian:certSIGN_Root_CA_G2.pem
# Adding debian:e-Szigno_Root_CA_2017.pem
# Adding debian:ePKI_Root_Certification_Authority.pem
# Adding debian:emSign_ECC_Root_CA_-_C3.pem
# Adding debian:emSign_ECC_Root_CA_-_G3.pem
# Adding debian:emSign_Root_CA_-_C1.pem
# Adding debian:emSign_Root_CA_-_G1.pem
# Adding debian:vTrus_ECC_Root_CA.pem
# Adding debian:vTrus_Root_CA.pem
# done.
# Setting up openjdk-21-jre:amd64 (21.0.5+11-1ubuntu1~24.04) ...
# Setting up default-jre-headless (2:1.21-75+exp1) ...
# Setting up default-jre (2:1.21-75+exp1) ...
# Setting up cuda-nvvp-12-6 (12.6.80-1) ...
# Setting up cuda-nsight-12-6 (12.6.77-1) ...
# Setting up cuda-visual-tools-12-6 (12.6.3-1) ...
# Setting up cuda-tools-12-6 (12.6.3-1) ...
# Setting up cuda-toolkit-12-6 (12.6.3-1) ...
# Setting up cuda-toolkit (12.6.3-1) ...
# Setting alternatives
# Processing triggers for libgdk-pixbuf-2.0-0:amd64 (2.42.10+dfsg-3ubuntu3.1) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#  Done installing cuda-toolkit

# %%
print(f"Apt update and upgrade")
commands = [
    'sudo apt-get -q update',
    'sudo apt-get -q upgrade -y'
]
print("Updating...")
for command in commands:
    print(f"++++ {command}")
    stdout, stderr = node1.execute(command)
    print(f"++++ {command}")
    stdout, stderr = node2.execute(command)
    
print("Done with apt update")
# Out:
# Apt update and upgrade
# Updating...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:2 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Hit:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease
# Get:6 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [585 kB]
# Get:7 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [7220 B]
# Get:8 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [800 kB]
# Get:9 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [52.0 kB]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [212 B]
# Get:11 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [208 B]
# Fetched 1827 kB in 2s (953 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q update
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble InRelease [256 kB]
# Get:2 http://security.ubuntu.com/ubuntu noble-security InRelease [126 kB]
# Get:3 http://security.ubuntu.com/ubuntu noble-security/main amd64 Packages [585 kB]
# Hit:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates InRelease
# Hit:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-backports InRelease
# Get:6 http://security.ubuntu.com/ubuntu noble-security/main amd64 Components [7220 B]
# Get:7 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Packages [800 kB]
# Get:8 http://security.ubuntu.com/ubuntu noble-security/universe amd64 Components [52.0 kB]
# Get:9 http://security.ubuntu.com/ubuntu noble-security/restricted amd64 Components [212 B]
# Get:10 http://security.ubuntu.com/ubuntu noble-security/multiverse amd64 Components [208 B]
# Hit:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2404/x86_64  InRelease
# Fetched 1827 kB in 18s (104 kB/s)
# Reading package lists...
# ++++ sudo apt-get -q upgrade -y
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# The following packages have been kept back:
#   linux-headers-generic linux-headers-virtual linux-image-virtual
#   linux-virtual
# The following packages will be upgraded:
#   apport apport-core-dump-handler bind9-dnsutils bind9-host bind9-libs
#   cloud-init curl fwupd gir1.2-packagekitglib-1.0 libcurl3t64-gnutls
#   libcurl4t64 libfwupd2 libgstreamer1.0-0 libnetplan1 libpackagekit-glib2-18
#   libudisks2-0 linux-libc-dev linux-tools-common netplan-generator netplan.io
#   packagekit packagekit-tools python3-apport python3-netplan
#   python3-problem-report sosreport ssh-import-id udisks2
# 28 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Need to get 13.2 MB of archives.
# After this operation, 273 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-problem-report all 2.28.1-0ubuntu3.3 [24.6 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-apport all 2.28.1-0ubuntu3.3 [92.3 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 apport-core-dump-handler all 2.28.1-0ubuntu3.3 [17.5 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 apport all 2.28.1-0ubuntu3.3 [84.5 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 netplan-generator amd64 1.1.1-1~ubuntu24.04.1 [60.8 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-netplan amd64 1.1.1-1~ubuntu24.04.1 [24.3 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 netplan.io amd64 1.1.1-1~ubuntu24.04.1 [68.5 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libnetplan1 amd64 1.1.1-1~ubuntu24.04.1 [131 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bind9-host amd64 1:9.18.30-0ubuntu0.24.04.1 [50.4 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bind9-dnsutils amd64 1:9.18.30-0ubuntu0.24.04.1 [155 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bind9-libs amd64 1:9.18.30-0ubuntu0.24.04.1 [1251 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 curl amd64 8.5.0-2ubuntu10.6 [226 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcurl4t64 amd64 8.5.0-2ubuntu10.6 [341 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcurl3t64-gnutls amd64 8.5.0-2ubuntu10.6 [333 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libfwupd2 amd64 1.9.27-0ubuntu1~24.04.1 [136 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 fwupd amd64 1.9.27-0ubuntu1~24.04.1 [4584 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libpackagekit-glib2-18 amd64 1.2.8-2ubuntu1.1 [120 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gir1.2-packagekitglib-1.0 amd64 1.2.8-2ubuntu1.1 [25.6 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgstreamer1.0-0 amd64 1.24.2-1ubuntu0.1 [1165 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 udisks2 amd64 2.10.1-6ubuntu1 [297 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libudisks2-0 amd64 2.10.1-6ubuntu1 [174 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 linux-libc-dev amd64 6.8.0-51.52 [1769 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 linux-tools-common all 6.8.0-51.52 [610 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 packagekit-tools amd64 1.2.8-2ubuntu1.1 [28.2 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 packagekit amd64 1.2.8-2ubuntu1.1 [434 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 sosreport amd64 4.7.2-0ubuntu1~24.04.2 [356 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 cloud-init all 24.4-0ubuntu1~24.04.2 [602 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 ssh-import-id all 5.11-0ubuntu2.24.04.1 [10.1 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 13.2 MB in 2s (8177 kB/s)
# (Reading database ... 97889 files and directories currently installed.)
# Preparing to unpack .../00-python3-problem-report_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking python3-problem-report (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../01-python3-apport_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking python3-apport (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../02-apport-core-dump-handler_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking apport-core-dump-handler (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../03-apport_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking apport (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../04-netplan-generator_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Adding 'diversion of /lib/systemd/system-generators/netplan to /lib/systemd/system-generators/netplan.usr-is-merged by netplan-generator'
# Unpacking netplan-generator (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../05-python3-netplan_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Unpacking python3-netplan (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../06-netplan.io_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Unpacking netplan.io (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../07-libnetplan1_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Unpacking libnetplan1:amd64 (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../08-bind9-host_1%3a9.18.30-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking bind9-host (1:9.18.30-0ubuntu0.24.04.1) over (1:9.18.28-0ubuntu0.24.04.1) ...
# Preparing to unpack .../09-bind9-dnsutils_1%3a9.18.30-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking bind9-dnsutils (1:9.18.30-0ubuntu0.24.04.1) over (1:9.18.28-0ubuntu0.24.04.1) ...
# Preparing to unpack .../10-bind9-libs_1%3a9.18.30-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking bind9-libs:amd64 (1:9.18.30-0ubuntu0.24.04.1) over (1:9.18.28-0ubuntu0.24.04.1) ...
# Preparing to unpack .../11-curl_8.5.0-2ubuntu10.6_amd64.deb ...
# Unpacking curl (8.5.0-2ubuntu10.6) over (8.5.0-2ubuntu10.5) ...
# Preparing to unpack .../12-libcurl4t64_8.5.0-2ubuntu10.6_amd64.deb ...
# Unpacking libcurl4t64:amd64 (8.5.0-2ubuntu10.6) over (8.5.0-2ubuntu10.5) ...
# Preparing to unpack .../13-libcurl3t64-gnutls_8.5.0-2ubuntu10.6_amd64.deb ...
# Unpacking libcurl3t64-gnutls:amd64 (8.5.0-2ubuntu10.6) over (8.5.0-2ubuntu10.5) ...
# Preparing to unpack .../14-libfwupd2_1.9.27-0ubuntu1~24.04.1_amd64.deb ...
# Unpacking libfwupd2:amd64 (1.9.27-0ubuntu1~24.04.1) over (1.9.24-1~24.04.1) ...
# Preparing to unpack .../15-fwupd_1.9.27-0ubuntu1~24.04.1_amd64.deb ...
# Unpacking fwupd (1.9.27-0ubuntu1~24.04.1) over (1.9.24-1~24.04.1) ...
# Preparing to unpack .../16-libpackagekit-glib2-18_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking libpackagekit-glib2-18:amd64 (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../17-gir1.2-packagekitglib-1.0_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-packagekitglib-1.0 (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../18-libgstreamer1.0-0_1.24.2-1ubuntu0.1_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.24.2-1ubuntu0.1) over (1.24.2-1) ...
# Preparing to unpack .../19-udisks2_2.10.1-6ubuntu1_amd64.deb ...
# Unpacking udisks2 (2.10.1-6ubuntu1) over (2.10.1-6build1) ...
# Preparing to unpack .../20-libudisks2-0_2.10.1-6ubuntu1_amd64.deb ...
# Unpacking libudisks2-0:amd64 (2.10.1-6ubuntu1) over (2.10.1-6build1) ...
# Preparing to unpack .../21-linux-libc-dev_6.8.0-51.52_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (6.8.0-51.52) over (6.8.0-49.49) ...
# Preparing to unpack .../22-linux-tools-common_6.8.0-51.52_all.deb ...
# Unpacking linux-tools-common (6.8.0-51.52) over (6.8.0-49.49) ...
# Preparing to unpack .../23-packagekit-tools_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking packagekit-tools (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../24-packagekit_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking packagekit (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../25-sosreport_4.7.2-0ubuntu1~24.04.2_amd64.deb ...
# Unpacking sosreport (4.7.2-0ubuntu1~24.04.2) over (4.7.2-0ubuntu1~24.04.1) ...
# Preparing to unpack .../26-cloud-init_24.4-0ubuntu1~24.04.2_all.deb ...
# Unpacking cloud-init (24.4-0ubuntu1~24.04.2) over (24.3.1-0ubuntu0~24.04.2) ...
# Preparing to unpack .../27-ssh-import-id_5.11-0ubuntu2.24.04.1_all.deb ...
# Unpacking ssh-import-id (5.11-0ubuntu2.24.04.1) over (5.11-0ubuntu2) ...
# Setting up libcurl4t64:amd64 (8.5.0-2ubuntu10.6) ...
# Setting up bind9-libs:amd64 (1:9.18.30-0ubuntu0.24.04.1) ...
# Setting up python3-problem-report (2.28.1-0ubuntu3.3) ...
# Setting up ssh-import-id (5.11-0ubuntu2.24.04.1) ...
# Setting up libcurl3t64-gnutls:amd64 (8.5.0-2ubuntu10.6) ...
# Setting up linux-libc-dev:amd64 (6.8.0-51.52) ...
# Setting up libpackagekit-glib2-18:amd64 (1.2.8-2ubuntu1.1) ...
# Setting up libnetplan1:amd64 (1.1.1-1~ubuntu24.04.1) ...
# Setting up python3-apport (2.28.1-0ubuntu3.3) ...
# Setting up gir1.2-packagekitglib-1.0 (1.2.8-2ubuntu1.1) ...
# Setting up sosreport (4.7.2-0ubuntu1~24.04.2) ...
# Setting up python3-netplan (1.1.1-1~ubuntu24.04.1) ...
# Setting up curl (8.5.0-2ubuntu10.6) ...
# Setting up netplan-generator (1.1.1-1~ubuntu24.04.1) ...
# Removing 'diversion of /lib/systemd/system-generators/netplan to /lib/systemd/system-generators/netplan.usr-is-merged by netplan-generator'
# Setting up bind9-host (1:9.18.30-0ubuntu0.24.04.1) ...
# Setting up linux-tools-common (6.8.0-51.52) ...
# Setting up libgstreamer1.0-0:amd64 (1.24.2-1ubuntu0.1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up libudisks2-0:amd64 (2.10.1-6ubuntu1) ...
# Setting up udisks2 (2.10.1-6ubuntu1) ...
# Setting up libfwupd2:amd64 (1.9.27-0ubuntu1~24.04.1) ...
# Setting up netplan.io (1.1.1-1~ubuntu24.04.1) ...
# Setting up packagekit (1.2.8-2ubuntu1.1) ...
# Setting up bind9-dnsutils (1:9.18.30-0ubuntu0.24.04.1) ...
# Setting up fwupd (1.9.27-0ubuntu1~24.04.1) ...
# fwupd-offline-update.service is a disabled or a static unit not running, not starting it.
# fwupd-refresh.service is a disabled or a static unit not running, not starting it.
# fwupd.service is a disabled or a static unit not running, not starting it.
# Setting up packagekit-tools (1.2.8-2ubuntu1.1) ...
# Setting up cloud-init (24.4-0ubuntu1~24.04.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Setting up apport-core-dump-handler (2.28.1-0ubuntu3.3) ...
# Setting up apport (2.28.1-0ubuntu3.3) ...
# apport-autoreport.service is a disabled or a static unit not running, not starting it.
# Processing triggers for dbus (1.14.10-4ubuntu4.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.3) ...
# Processing triggers for rsyslog (8.2312.0-3ubuntu9) ...
# Processing triggers for man-db (2.12.0-4build2) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#  ++++ sudo apt-get -q upgrade -y
# Reading package lists...
# Building dependency tree...
# Reading state information...
# Calculating upgrade...
# The following packages have been kept back:
#   linux-headers-generic linux-headers-virtual linux-image-virtual
#   linux-virtual
# The following packages will be upgraded:
#   apport apport-core-dump-handler bind9-dnsutils bind9-host bind9-libs
#   cloud-init curl fwupd gir1.2-packagekitglib-1.0 libcurl3t64-gnutls
#   libcurl4t64 libfwupd2 libgstreamer1.0-0 libnetplan1 libpackagekit-glib2-18
#   libudisks2-0 linux-libc-dev linux-tools-common netplan-generator netplan.io
#   packagekit packagekit-tools python3-apport python3-netplan
#   python3-problem-report sosreport ssh-import-id udisks2
# 28 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Need to get 13.2 MB of archives.
# After this operation, 273 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-problem-report all 2.28.1-0ubuntu3.3 [24.6 kB]
# Get:2 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-apport all 2.28.1-0ubuntu3.3 [92.3 kB]
# Get:3 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 apport-core-dump-handler all 2.28.1-0ubuntu3.3 [17.5 kB]
# Get:4 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 apport all 2.28.1-0ubuntu3.3 [84.5 kB]
# Get:5 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 netplan-generator amd64 1.1.1-1~ubuntu24.04.1 [60.8 kB]
# Get:6 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 python3-netplan amd64 1.1.1-1~ubuntu24.04.1 [24.3 kB]
# Get:7 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 netplan.io amd64 1.1.1-1~ubuntu24.04.1 [68.5 kB]
# Get:8 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libnetplan1 amd64 1.1.1-1~ubuntu24.04.1 [131 kB]
# Get:9 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bind9-host amd64 1:9.18.30-0ubuntu0.24.04.1 [50.4 kB]
# Get:10 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bind9-dnsutils amd64 1:9.18.30-0ubuntu0.24.04.1 [155 kB]
# Get:11 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 bind9-libs amd64 1:9.18.30-0ubuntu0.24.04.1 [1251 kB]
# Get:12 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 curl amd64 8.5.0-2ubuntu10.6 [226 kB]
# Get:13 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcurl4t64 amd64 8.5.0-2ubuntu10.6 [341 kB]
# Get:14 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libcurl3t64-gnutls amd64 8.5.0-2ubuntu10.6 [333 kB]
# Get:15 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libfwupd2 amd64 1.9.27-0ubuntu1~24.04.1 [136 kB]
# Get:16 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 fwupd amd64 1.9.27-0ubuntu1~24.04.1 [4584 kB]
# Get:17 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libpackagekit-glib2-18 amd64 1.2.8-2ubuntu1.1 [120 kB]
# Get:18 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 gir1.2-packagekitglib-1.0 amd64 1.2.8-2ubuntu1.1 [25.6 kB]
# Get:19 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libgstreamer1.0-0 amd64 1.24.2-1ubuntu0.1 [1165 kB]
# Get:20 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 udisks2 amd64 2.10.1-6ubuntu1 [297 kB]
# Get:21 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 libudisks2-0 amd64 2.10.1-6ubuntu1 [174 kB]
# Get:22 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 linux-libc-dev amd64 6.8.0-51.52 [1769 kB]
# Get:23 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 linux-tools-common all 6.8.0-51.52 [610 kB]
# Get:24 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 packagekit-tools amd64 1.2.8-2ubuntu1.1 [28.2 kB]
# Get:25 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 packagekit amd64 1.2.8-2ubuntu1.1 [434 kB]
# Get:26 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 sosreport amd64 4.7.2-0ubuntu1~24.04.2 [356 kB]
# Get:27 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 cloud-init all 24.4-0ubuntu1~24.04.2 [602 kB]
# Get:28 http://nova.clouds.archive.ubuntu.com/ubuntu noble-updates/main amd64 ssh-import-id all 5.11-0ubuntu2.24.04.1 [10.1 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
#  Fetched 13.2 MB in 1s (8809 kB/s)
# (Reading database ... 97889 files and directories currently installed.)
# Preparing to unpack .../00-python3-problem-report_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking python3-problem-report (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../01-python3-apport_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking python3-apport (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../02-apport-core-dump-handler_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking apport-core-dump-handler (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../03-apport_2.28.1-0ubuntu3.3_all.deb ...
# Unpacking apport (2.28.1-0ubuntu3.3) over (2.28.1-0ubuntu3.1) ...
# Preparing to unpack .../04-netplan-generator_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Adding 'diversion of /lib/systemd/system-generators/netplan to /lib/systemd/system-generators/netplan.usr-is-merged by netplan-generator'
# Unpacking netplan-generator (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../05-python3-netplan_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Unpacking python3-netplan (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../06-netplan.io_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Unpacking netplan.io (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../07-libnetplan1_1.1.1-1~ubuntu24.04.1_amd64.deb ...
# Unpacking libnetplan1:amd64 (1.1.1-1~ubuntu24.04.1) over (1.0.1-1ubuntu2~24.04.1) ...
# Preparing to unpack .../08-bind9-host_1%3a9.18.30-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking bind9-host (1:9.18.30-0ubuntu0.24.04.1) over (1:9.18.28-0ubuntu0.24.04.1) ...
# Preparing to unpack .../09-bind9-dnsutils_1%3a9.18.30-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking bind9-dnsutils (1:9.18.30-0ubuntu0.24.04.1) over (1:9.18.28-0ubuntu0.24.04.1) ...
# Preparing to unpack .../10-bind9-libs_1%3a9.18.30-0ubuntu0.24.04.1_amd64.deb ...
# Unpacking bind9-libs:amd64 (1:9.18.30-0ubuntu0.24.04.1) over (1:9.18.28-0ubuntu0.24.04.1) ...
# Preparing to unpack .../11-curl_8.5.0-2ubuntu10.6_amd64.deb ...
# Unpacking curl (8.5.0-2ubuntu10.6) over (8.5.0-2ubuntu10.5) ...
# Preparing to unpack .../12-libcurl4t64_8.5.0-2ubuntu10.6_amd64.deb ...
# Unpacking libcurl4t64:amd64 (8.5.0-2ubuntu10.6) over (8.5.0-2ubuntu10.5) ...
# Preparing to unpack .../13-libcurl3t64-gnutls_8.5.0-2ubuntu10.6_amd64.deb ...
# Unpacking libcurl3t64-gnutls:amd64 (8.5.0-2ubuntu10.6) over (8.5.0-2ubuntu10.5) ...
# Preparing to unpack .../14-libfwupd2_1.9.27-0ubuntu1~24.04.1_amd64.deb ...
# Unpacking libfwupd2:amd64 (1.9.27-0ubuntu1~24.04.1) over (1.9.24-1~24.04.1) ...
# Preparing to unpack .../15-fwupd_1.9.27-0ubuntu1~24.04.1_amd64.deb ...
# Unpacking fwupd (1.9.27-0ubuntu1~24.04.1) over (1.9.24-1~24.04.1) ...
# Preparing to unpack .../16-libpackagekit-glib2-18_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking libpackagekit-glib2-18:amd64 (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../17-gir1.2-packagekitglib-1.0_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking gir1.2-packagekitglib-1.0 (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../18-libgstreamer1.0-0_1.24.2-1ubuntu0.1_amd64.deb ...
# Unpacking libgstreamer1.0-0:amd64 (1.24.2-1ubuntu0.1) over (1.24.2-1) ...
# Preparing to unpack .../19-udisks2_2.10.1-6ubuntu1_amd64.deb ...
# Unpacking udisks2 (2.10.1-6ubuntu1) over (2.10.1-6build1) ...
# Preparing to unpack .../20-libudisks2-0_2.10.1-6ubuntu1_amd64.deb ...
# Unpacking libudisks2-0:amd64 (2.10.1-6ubuntu1) over (2.10.1-6build1) ...
# Preparing to unpack .../21-linux-libc-dev_6.8.0-51.52_amd64.deb ...
# Unpacking linux-libc-dev:amd64 (6.8.0-51.52) over (6.8.0-49.49) ...
# Preparing to unpack .../22-linux-tools-common_6.8.0-51.52_all.deb ...
# Unpacking linux-tools-common (6.8.0-51.52) over (6.8.0-49.49) ...
# Preparing to unpack .../23-packagekit-tools_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking packagekit-tools (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../24-packagekit_1.2.8-2ubuntu1.1_amd64.deb ...
# Unpacking packagekit (1.2.8-2ubuntu1.1) over (1.2.8-2build3) ...
# Preparing to unpack .../25-sosreport_4.7.2-0ubuntu1~24.04.2_amd64.deb ...
# Unpacking sosreport (4.7.2-0ubuntu1~24.04.2) over (4.7.2-0ubuntu1~24.04.1) ...
# Preparing to unpack .../26-cloud-init_24.4-0ubuntu1~24.04.2_all.deb ...
# Unpacking cloud-init (24.4-0ubuntu1~24.04.2) over (24.3.1-0ubuntu0~24.04.2) ...
# Preparing to unpack .../27-ssh-import-id_5.11-0ubuntu2.24.04.1_all.deb ...
# Unpacking ssh-import-id (5.11-0ubuntu2.24.04.1) over (5.11-0ubuntu2) ...
# Setting up libcurl4t64:amd64 (8.5.0-2ubuntu10.6) ...
# Setting up bind9-libs:amd64 (1:9.18.30-0ubuntu0.24.04.1) ...
# Setting up python3-problem-report (2.28.1-0ubuntu3.3) ...
# Setting up ssh-import-id (5.11-0ubuntu2.24.04.1) ...
# Setting up libcurl3t64-gnutls:amd64 (8.5.0-2ubuntu10.6) ...
# Setting up linux-libc-dev:amd64 (6.8.0-51.52) ...
# Setting up libpackagekit-glib2-18:amd64 (1.2.8-2ubuntu1.1) ...
# Setting up libnetplan1:amd64 (1.1.1-1~ubuntu24.04.1) ...
# Setting up python3-apport (2.28.1-0ubuntu3.3) ...
# Setting up gir1.2-packagekitglib-1.0 (1.2.8-2ubuntu1.1) ...
# Setting up sosreport (4.7.2-0ubuntu1~24.04.2) ...
# Setting up python3-netplan (1.1.1-1~ubuntu24.04.1) ...
# Setting up curl (8.5.0-2ubuntu10.6) ...
# Setting up netplan-generator (1.1.1-1~ubuntu24.04.1) ...
# Removing 'diversion of /lib/systemd/system-generators/netplan to /lib/systemd/system-generators/netplan.usr-is-merged by netplan-generator'
# Setting up bind9-host (1:9.18.30-0ubuntu0.24.04.1) ...
# Setting up linux-tools-common (6.8.0-51.52) ...
# Setting up libgstreamer1.0-0:amd64 (1.24.2-1ubuntu0.1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up libudisks2-0:amd64 (2.10.1-6ubuntu1) ...
# Setting up udisks2 (2.10.1-6ubuntu1) ...
# Setting up libfwupd2:amd64 (1.9.27-0ubuntu1~24.04.1) ...
# Setting up netplan.io (1.1.1-1~ubuntu24.04.1) ...
# Setting up packagekit (1.2.8-2ubuntu1.1) ...
# Setting up bind9-dnsutils (1:9.18.30-0ubuntu0.24.04.1) ...
# Setting up fwupd (1.9.27-0ubuntu1~24.04.1) ...
# fwupd-offline-update.service is a disabled or a static unit not running, not starting it.
# fwupd-refresh.service is a disabled or a static unit not running, not starting it.
# fwupd.service is a disabled or a static unit not running, not starting it.
# Setting up packagekit-tools (1.2.8-2ubuntu1.1) ...
# Setting up cloud-init (24.4-0ubuntu1~24.04.2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Setting up apport-core-dump-handler (2.28.1-0ubuntu3.3) ...
# Setting up apport (2.28.1-0ubuntu3.3) ...
# apport-autoreport.service is a disabled or a static unit not running, not starting it.
# Processing triggers for dbus (1.14.10-4ubuntu4.1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.39-0ubuntu8.3) ...
# Processing triggers for rsyslog (8.2312.0-3ubuntu9) ...
# Processing triggers for man-db (2.12.0-4build2) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
#   No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#  Done with apt update

# %% [markdown]
# And once CUDA is installed, reboot the machine.

# %%
node1.upload_file('./bashrc', './.bashrc')
node2.upload_file('./bashrc', './.bashrc')
# Out:
# <SFTPAttributes: [ size=4264 uid=1000 gid=1000 mode=0o100644 atime=1736790795 mtime=1736808553 ]>

# %%
reboot = 'sudo reboot'

print(reboot)
node1.execute(reboot)

slice.wait_ssh(timeout=360,interval=10,progress=True)

print("Now testing SSH abilites to reconnect...",end="")
slice.update()
slice.test_ssh()
print("Reconnected!")
# Out:
# sudo reboot
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice ... ssh successful
# Now testing SSH abilites to reconnect...Reconnected!

# %%
reboot = 'sudo reboot'

print(reboot)
node2.execute(reboot)

slice.wait_ssh(timeout=360,interval=10,progress=True)

print("Now testing SSH abilites to reconnect...",end="")
slice.update()
slice.test_ssh()
print("Reconnected!")
# Out:
# sudo reboot
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice ... ssh successful
# Now testing SSH abilites to reconnect...Reconnected!

# %% [markdown]
# ## Testing the GPU and CUDA Installation
#
# First, verify that the Nvidia drivers recognize the GPU by running `nvidia-smi`.

# %%
stdout, stderr = node1.execute("nvidia-smi")

print(f"stdout: {stdout}")
# Out:
#  bash: line 1: nvidia-smi: command not found
#  stdout:

# %%
stdout, stderr = node2.execute("nvidia-smi")

print(f"stdout: {stdout}")
# Out:
#  bash: line 1: nvidia-smi: command not found
#  stdout:

# %% [markdown]
# Now, let's upload the following "Hello World" CUDA program file to the node.
#
# `hello-world.cu`
#
# *Source: https://computer-graphics.se/multicore/pdf/hello-world.cu*
#
# *Author: Ingemar Ragnemalm*
#
# >This file is from *"The real "Hello World!" for CUDA, OpenCL and GLSL!"* (https://computer-graphics.se/hello-world-for-cuda.html), written by Ingemar Ragnemalm, programmer and CUDA teacher. The only changes (if you download the original file from the website) are to additionally `#include <unistd.h>`, as `sleep()` is now a fuction defined in the `unistd.h` library.

# %%
node1.upload_file('./hello-world.cu', 'hello-world.cu')
node2.upload_file('./hello-world.cu', 'hello-world.cu')
# Out:
# <SFTPAttributes: [ size=1110 uid=1000 gid=1000 mode=0o100664 atime=1736790908 mtime=1736790908 ]>

# %%
# never do this on FABRIC --see below for using slice_key -- but do here for cluster communications test
node1.upload_file('id_rsa', '.ssh/id_rsa')
node1.upload_file('id_rsa.pub', '.ssh/id_rsa.pub')
node2.upload_file('id_rsa', '.ssh/id_rsa')
node2.upload_file('id_rsa.pub', '.ssh/id_rsa.pub')
stdout, stderr = node1.execute(f"chmod 600 ~/.ssh/id_rsa")
stdout, stderr = node2.execute(f"chmod 600 ~/.ssh/id_rsa")
stdout, stderr = node1.execute(f"chmod 644 ~/.ssh/id_rsa.pub")
stdout, stderr = node2.execute(f"chmod 644 ~/.ssh/id_rsa.pub")

# %%
#grab latest fabric slice_key from fabric_config directory in case it changed
node1.upload_file('/home/fabric/work/fabric_config/slice_key', '.ssh/slice_key')
node2.upload_file('/home/fabric/work/fabric_config/slice_key', '.ssh/slice_key')
stdout, stderr = node1.execute(f"chmod 600 ~/.ssh/slice_key")
stdout, stderr = node2.execute(f"chmod 600 ~/.ssh/slice_key")
print(f'Use slice key explicitly to connect to nodes:  ssh -i ~/.ssh/slice_key ubuntu@192.168.100.2')
# Out:
# Use slice key explicitly to connect to nodes:  ssh -i ~/.ssh/slice_key ubuntu@192.168.100.2

# %%
#repair network interfaces after reboot
stdout, stderr = node1.execute(f"sudo apt install net-tools -y")
stdout, stderr = node1.execute(f"sudo ifconfig enp7s0 down")
stdout, stderr = node1.execute(f"sudo ip addr add 192.168.100.1/24 dev enp7s0")
stdout, stderr = node1.execute(f"sudo ifconfig enp7s0 up")
stdout, stderr = node1.execute(f"sudo ifconfig enp7s0")

stdout, stderr = node2.execute(f"sudo apt install net-tools -y")
stdout, stderr = node2.execute(f"sudo ifconfig enp7s0 down")
stdout, stderr = node2.execute(f"sudo ip addr add 192.168.100.2/24 dev enp7s0")
stdout, stderr = node2.execute(f"sudo ifconfig enp7s0 up")
stdout, stderr = node1.execute(f"sudo ifconfig enp7s0")
# Out:
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 204 kB of archives.
# After this operation, 811 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 net-tools amd64 2.10-0.1ubuntu4 [204 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 204 kB in 1s (224 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 97897 files and directories currently installed.)
# Preparing to unpack .../net-tools_2.10-0.1ubuntu4_amd64.deb ...
# Unpacking net-tools (2.10-0.1ubuntu4) ...
# Setting up net-tools (2.10-0.1ubuntu4) ...
# Processing triggers for man-db (2.12.0-4build2) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#  enp7s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 192.168.100.1  netmask 255.255.255.0  broadcast 0.0.0.0
#         inet6 fe80::1d:b9ff:fe31:e723  prefixlen 64  scopeid 0x20<link>
#         ether 02:1d:b9:31:e7:23  txqueuelen 1000  (Ethernet)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 5  bytes 426 (426.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0
#
# Reading package lists...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Building dependency tree...
# Reading state information...
# The following NEW packages will be installed:
#   net-tools
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 204 kB of archives.
# After this operation, 811 kB of additional disk space will be used.
# Get:1 http://nova.clouds.archive.ubuntu.com/ubuntu noble/main amd64 net-tools amd64 2.10-0.1ubuntu4 [204 kB]
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#   dpkg-preconfigure: unable to re-open stdin:
#  Fetched 204 kB in 1s (243 kB/s)
# Selecting previously unselected package net-tools.
# (Reading database ... 97897 files and directories currently installed.)
# Preparing to unpack .../net-tools_2.10-0.1ubuntu4_amd64.deb ...
# Unpacking net-tools (2.10-0.1ubuntu4) ...
# Setting up net-tools (2.10-0.1ubuntu4) ...
# Processing triggers for man-db (2.12.0-4build2) ...
#  debconf: unable to initialize frontend: Dialog
# debconf: (Dialog frontend will not work on a dumb terminal, an emacs shell buffer, or without a controlling terminal.)
# debconf: falling back to frontend: Readline
#   debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
#
# Running kernel seems to be up-to-date.
#
# No services need to be restarted.
#
# No containers need to be restarted.
#
# No user sessions are running outdated binaries.
#
# No VM guests are running outdated hypervisor (qemu) binaries on this host.
#   enp7s0: ERROR while getting interface flags: No such device
#   Cannot find device "enp7s0"
#   enp7s0: ERROR while getting interface flags: No such device
#  enp7s0: flags=4163<UP,BROADCAST,RUNNING,MULTICAST>  mtu 1500
#         inet 192.168.100.1  netmask 255.255.255.0  broadcast 0.0.0.0
#         inet6 fe80::1d:b9ff:fe31:e723  prefixlen 64  scopeid 0x20<link>
#         ether 02:1d:b9:31:e7:23  txqueuelen 1000  (Ethernet)
#         RX packets 0  bytes 0 (0.0 B)
#         RX errors 0  dropped 0  overruns 0  frame 0
#         TX packets 8  bytes 656 (656.0 B)
#         TX errors 0  dropped 0 overruns 0  carrier 0  collisions 0

# %%
#node1.upload_file(' ./lightning_mnist_example.ipynb', 'lightning_mnist_example.ipynb')
#node2.upload_file('./lightning_mnist_example.ipynb', 'lightning_mnist_example.ipynb')

# %%
#get ssh commands
print(f"SSH Command: {node1.get_ssh_command()}")
print(f"SSH Command: {node2.get_ssh_command()}")
# Out:
# SSH Command: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fe43:6d39
# SSH Command: ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fea7:bb66

# %%
node1.upload_file('./lightning_mnist_example-2gpu.py', 'lightning_mnist_example.py')
node1.upload_file('./installer.sh', './installer.sh')
node1.upload_file('./invertArray.py', './invertArray.py')

node2.upload_file('./lightning_mnist_example-2gpu.py', 'lightning_mnist_example.py')
node2.upload_file('./installer.sh', './installer.sh')
node2.upload_file('./invertArray.py', './invertArray.py')


#node.upload_file('./lightning_mnist_example-install1.py', 'lightning_mnist_example-install1.py')
#node.upload_file('./lightning_mnist_example-install2.py', 'lightning_mnist_example-install2.py')
# Out:
# <SFTPAttributes: [ size=242 uid=1000 gid=1000 mode=0o100664 atime=1736790972 mtime=1736808632 ]>

# %%
stdout, stderr = node1.execute("bash ./installer.sh")
print(f"stdout: {stdout}")

stdout, stderr = node2.execute("bash ./installer.sh")
print(f"stdout: {stdout}")
# Out:
# Reading package lists...
# Building dependency tree...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Reading state information...
# ubuntu-drivers-common is already the newest version (1:0.9.7.6ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
#  udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   ERROR:root:aplay command not found
#  == /sys/devices/pci0000:00/0000:00:02.6/0000:08:00.0 ==
# modalias : pci:v000010DEd00002235sv000010DEsd0000145Abc03sc02i00
# vendor   : NVIDIA Corporation
# model    : GA102GL [A40]
# driver   : nvidia-driver-550 - third-party non-free
# driver   : nvidia-driver-565-open - third-party non-free
# driver   : nvidia-driver-555-open - third-party non-free
# driver   : nvidia-driver-470-server - distro non-free
# driver   : nvidia-driver-535-server - distro non-free
# driver   : nvidia-driver-535 - distro non-free
# driver   : nvidia-driver-535-server-open - distro non-free
# driver   : nvidia-driver-535-open - distro non-free
# driver   : nvidia-driver-565 - third-party non-free recommended
# driver   : nvidia-driver-555 - third-party non-free
# driver   : nvidia-driver-560 - third-party non-free
# driver   : nvidia-driver-550-open - third-party non-free
# driver   : nvidia-driver-470 - distro non-free
# driver   : nvidia-driver-560-open - third-party non-free
# driver   : xserver-xorg-video-nouveau - distro free builtin
#
#  udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   ERROR:root:aplay command not found
#  All the available drivers are already installed.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-full is already the newest version (3.12.3-0ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3.12-venv is already the newest version (3.12.3-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-pip is already the newest version (24.0+dfsg-1ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# pip 24.0 from /usr/lib/python3/dist-packages/pip (python 3.12)
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# Collecting torchvision
#   Downloading torchvision-0.20.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting ray
#   Downloading ray-2.40.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 752.4 kB/s eta 0:00:00
# Requirement already satisfied: numpy in ./ray-venv/lib/python3.12/site-packages (2.2.1)
# Collecting packaging>17.1 (from torchmetrics)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting torch>=2.0.0 (from torchmetrics)
#   Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting tqdm>=4.57.0 (from pytorch_lightning)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# Collecting PyYAML>=5.4 (from pytorch_lightning)
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting fsspec>=2022.5.0 (from fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions>=4.4.0 (from pytorch_lightning)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting filelock (from torch>=2.0.0->torchmetrics)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting networkx (from torch>=2.0.0->torchmetrics)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=2.0.0->torchmetrics)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=2.0.0->torchmetrics)
#   Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting setuptools (from torch>=2.0.0->torchmetrics)
#   Downloading setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sympy==1.13.1 (from torch>=2.0.0->torchmetrics)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=2.0.0->torchmetrics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting click>=7.0 (from ray)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonschema (from ray)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray)
#   Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting aiosignal (from ray)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist (from ray)
#   Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting requests (from ray)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting aiohttp>=3.7 (from ray[default])
#   Downloading aiohttp-3.11.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting aiohttp-cors (from ray[default])
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default])
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[default])
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting opencensus (from ray[default])
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 (from ray[default])
#   Downloading pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Collecting prometheus-client>=0.7.1 (from ray[default])
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting smart-open (from ray[default])
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default])
#   Downloading virtualenv-20.28.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting grpcio>=1.42.0 (from ray[default])
#   Downloading grpcio-1.69.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting memray (from ray[default])
#   Downloading memray-1.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting tensorboardX>=1.9 (from ray[train])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting pyarrow>=9.0.0 (from ray[train])
#   Downloading pyarrow-18.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp>=3.7->ray[default])
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.7->ray[default])
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[default])
#   Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.7->ray[default])
#   Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.7->ray[default])
#   Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 3.1 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0 (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default])
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default])
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default])
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting platformdirs<5,>=3.9.1 (from virtualenv!=20.21.1,>=20.0.24->ray[default])
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->ray)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray)
#   Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting rich>=11.2.0 (from memray->ray[default])
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting textual>=0.41.0 (from memray->ray[default])
#   Downloading textual-1.0.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default])
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[default])
#   Downloading google_api_core-2.24.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->ray)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->ray)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->ray)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->ray)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting wrapt (from smart-open->ray[default])
#   Downloading wrapt-1.17.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading google_auth-2.37.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=2.0.0->torchmetrics)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.2.0->memray->ray[default])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=11.2.0->memray->ray[default])
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.2.0->memray->ray[default])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting linkify-it-py<3,>=1 (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting mdit-py-plugins (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting uc-micro-py (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 4.0 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 22.5 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp312-cp312-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 32.0 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 8.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 34.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 39.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 84.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 14.3 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 26.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 21.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 12.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 33.1 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 19.6 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 51.1 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 13.2 MB/s eta 0:00:00
# Downloading ray-2.40.0-cp312-cp312-manylinux2014_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 25.1 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 35.9 MB/s eta 0:00:00
# Downloading aiohttp-3.11.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 85.8 MB/s eta 0:00:00
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 19.4 MB/s eta 0:00:00
# Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 36.7 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 33.8 MB/s eta 0:00:00
# Downloading grpcio-1.69.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 50.0 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.4/401.4 kB 55.5 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 16.6 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 40.9 MB/s eta 0:00:00
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 14.1 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 51.4 MB/s eta 0:00:00
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 100.7 MB/s eta 0:00:00
# Downloading pyarrow-18.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (40.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 27.1 MB/s eta 0:00:00
# Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 56.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 36.1 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 39.6 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 64.6 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 67.2 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 21.2 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 16.3 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 51.9 MB/s eta 0:00:00
# Downloading virtualenv-20.28.1-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 40.4 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 35.1 MB/s eta 0:00:00
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 16.9 MB/s eta 0:00:00
# Downloading memray-1.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 40.1 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 24.1 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 15.3 MB/s eta 0:00:00
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 15.2 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 15.5 MB/s eta 0:00:00
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 31.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 kB 27.1 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 61.7 MB/s eta 0:00:00
# Downloading google_api_core-2.24.0-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.6/158.6 kB 29.0 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 11.4 MB/s eta 0:00:00
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 26.2 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 26.8 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.6/243.6 kB 40.7 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 41.2 MB/s eta 0:00:00
# Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 52.3 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading textual-1.0.0-py3-none-any.whl (660 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 71.1 MB/s eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 26.2 MB/s eta 0:00:00
# Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.9/336.9 kB 51.6 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 98.5 MB/s eta 0:00:00
# Downloading setuptools-75.8.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.2 MB/s eta 0:00:00
# Downloading wrapt-1.17.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 19.3 MB/s eta 0:00:00
# Downloading google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 38.3 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.7/221.7 kB 41.0 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 17.0 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 66.7 MB/s eta 0:00:00
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 12.3 MB/s eta 0:00:00
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 91.2 MB/s eta 0:00:00
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 32.8 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 14.0 MB/s eta 0:00:00
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 16.3 MB/s eta 0:00:00
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: pytz, py-spy, opencensus-context, mpmath, distlib, colorful, wrapt, urllib3, uc-micro-py, tzdata, typing-extensions, tqdm, sympy, six, setuptools, rpds-py, PyYAML, pygments, pyasn1, pyarrow, protobuf, propcache, prometheus-client, platformdirs, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, multidict, msgpack, mdurl, MarkupSafe, idna, grpcio, fsspec, frozenlist, filelock, click, charset-normalizer, certifi, cachetools, attrs, annotated-types, aiohappyeyeballs, yarl, virtualenv, triton, tensorboardX, smart-open, rsa, requests, referencing, python-dateutil, pydantic-core, pyasn1-modules, proto-plus, nvidia-cusparse-cu12, nvidia-cudnn-cu12, markdown-it-py, linkify-it-py, lightning-utilities, jinja2, googleapis-common-protos, aiosignal, rich, pydantic, pandas, nvidia-cusolver-cu12, mdit-py-plugins, jsonschema-specifications, google-auth, aiohttp, torch, jsonschema, google-api-core, aiohttp-cors, torchvision, torchmetrics, textual, ray, opencensus, pytorch_lightning, memray
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiohttp-cors-0.7.0 aiosignal-1.3.2 annotated-types-0.7.0 attrs-24.3.0 cachetools-5.5.0 certifi-2024.12.14 charset-normalizer-3.4.1 click-8.1.8 colorful-0.5.6 distlib-0.3.9 filelock-3.16.1 frozenlist-1.5.0 fsspec-2024.12.0 google-api-core-2.24.0 google-auth-2.37.0 googleapis-common-protos-1.66.0 grpcio-1.69.0 idna-3.10 jinja2-3.1.5 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 lightning-utilities-0.11.9 linkify-it-py-2.0.3 markdown-it-py-3.0.0 mdit-py-plugins-0.4.2 mdurl-0.1.2 memray-1.15.0 mpmath-1.3.0 msgpack-1.1.0 multidict-6.1.0 networkx-3.4.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opencensus-0.11.4 opencensus-context-0.1.3 packaging-24.2 pandas-2.2.3 pillow-11.1.0 platformdirs-4.3.6 prometheus-client-0.21.1 propcache-0.2.1 proto-plus-1.25.0 protobuf-5.29.3 py-spy-0.4.0 pyarrow-18.1.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.10.5 pydantic-core-2.27.2 pygments-2.19.1 python-dateutil-2.9.0.post0 pytorch_lightning-2.5.0.post0 pytz-2024.2 ray-2.40.0 referencing-0.35.1 requests-2.32.3 rich-13.9.4 rpds-py-0.22.3 rsa-4.9 setuptools-75.8.0 six-1.17.0 smart-open-7.1.0 sympy-1.13.1 tensorboardX-2.6.2.2 textual-1.0.0 torch-2.5.1 torchmetrics-1.6.1 torchvision-0.20.1 tqdm-4.67.1 triton-3.1.0 typing-extensions-4.12.2 tzdata-2024.2 uc-micro-py-1.0.3 urllib3-2.3.0 virtualenv-20.28.1 wrapt-1.17.1 yarl-1.18.3
# stdout: Reading package lists...
# Building dependency tree...
# Reading state information...
# ubuntu-drivers-common is already the newest version (1:0.9.7.6ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# == /sys/devices/pci0000:00/0000:00:02.6/0000:08:00.0 ==
# modalias : pci:v000010DEd00002235sv000010DEsd0000145Abc03sc02i00
# vendor   : NVIDIA Corporation
# model    : GA102GL [A40]
# driver   : nvidia-driver-550 - third-party non-free
# driver   : nvidia-driver-565-open - third-party non-free
# driver   : nvidia-driver-555-open - third-party non-free
# driver   : nvidia-driver-470-server - distro non-free
# driver   : nvidia-driver-535-server - distro non-free
# driver   : nvidia-driver-535 - distro non-free
# driver   : nvidia-driver-535-server-open - distro non-free
# driver   : nvidia-driver-535-open - distro non-free
# driver   : nvidia-driver-565 - third-party non-free recommended
# driver   : nvidia-driver-555 - third-party non-free
# driver   : nvidia-driver-560 - third-party non-free
# driver   : nvidia-driver-550-open - third-party non-free
# driver   : nvidia-driver-470 - distro non-free
# driver   : nvidia-driver-560-open - third-party non-free
# driver   : xserver-xorg-video-nouveau - distro free builtin
#
# All the available drivers are already installed.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-full is already the newest version (3.12.3-0ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3.12-venv is already the newest version (3.12.3-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-pip is already the newest version (24.0+dfsg-1ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# pip 24.0 from /usr/lib/python3/dist-packages/pip (python 3.12)
# Collecting torchmetrics
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting pytorch_lightning
#   Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl.metadata (21 kB)
# Collecting torchvision
#   Downloading torchvision-0.20.1-cp312-cp312-manylinux1_x86_64.whl.metadata (6.1 kB)
# Collecting ray
#   Downloading ray-2.40.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 752.4 kB/s eta 0:00:00
# Requirement already satisfied: numpy in ./ray-venv/lib/python3.12/site-packages (2.2.1)
# Collecting packaging>17.1 (from torchmetrics)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting torch>=2.0.0 (from torchmetrics)
#   Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting tqdm>=4.57.0 (from pytorch_lightning)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 3.0 MB/s eta 0:00:00
# Collecting PyYAML>=5.4 (from pytorch_lightning)
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting fsspec>=2022.5.0 (from fsspec[http]>=2022.5.0->pytorch_lightning)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Collecting typing-extensions>=4.4.0 (from pytorch_lightning)
#   Downloading typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision)
#   Downloading pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting filelock (from torch>=2.0.0->torchmetrics)
#   Downloading filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting networkx (from torch>=2.0.0->torchmetrics)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=2.0.0->torchmetrics)
#   Downloading jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->torchmetrics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.1.0 (from torch>=2.0.0->torchmetrics)
#   Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Collecting setuptools (from torch>=2.0.0->torchmetrics)
#   Downloading setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting sympy==1.13.1 (from torch>=2.0.0->torchmetrics)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=2.0.0->torchmetrics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting click>=7.0 (from ray)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting jsonschema (from ray)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting msgpack<2.0.0,>=1.0.0 (from ray)
#   Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Collecting protobuf!=3.19.5,>=3.15.3 (from ray)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting aiosignal (from ray)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting frozenlist (from ray)
#   Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting requests (from ray)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting aiohttp>=3.7 (from ray[default])
#   Downloading aiohttp-3.11.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting aiohttp-cors (from ray[default])
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default])
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[default])
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Collecting opencensus (from ray[default])
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Collecting pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 (from ray[default])
#   Downloading pydantic-2.10.5-py3-none-any.whl.metadata (30 kB)
# Collecting prometheus-client>=0.7.1 (from ray[default])
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting smart-open (from ray[default])
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default])
#   Downloading virtualenv-20.28.1-py3-none-any.whl.metadata (4.5 kB)
# Collecting grpcio>=1.42.0 (from ray[default])
#   Downloading grpcio-1.69.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting memray (from ray[default])
#   Downloading memray-1.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Collecting tensorboardX>=1.9 (from ray[train])
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting pyarrow>=9.0.0 (from ray[train])
#   Downloading pyarrow-18.1.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting python-dateutil>=2.8.2 (from pandas)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp>=3.7->ray[default])
#   Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp>=3.7->ray[default])
#   Downloading attrs-24.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.7->ray[default])
#   Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.7->ray[default])
#   Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.7->ray[default])
#   Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 3.1 MB/s eta 0:00:00
# Collecting annotated-types>=0.6.0 (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default])
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.27.2 (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default])
#   Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default])
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting platformdirs<5,>=3.9.1 (from virtualenv!=20.21.1,>=20.0.24->ray[default])
#   Downloading platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->ray)
#   Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema->ray)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->ray)
#   Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Collecting rich>=11.2.0 (from memray->ray[default])
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting textual>=0.41.0 (from memray->ray[default])
#   Downloading textual-1.0.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default])
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting google-api-core<3.0.0,>=1.0.0 (from opencensus->ray[default])
#   Downloading google_api_core-2.24.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests->ray)
#   Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->ray)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->ray)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->ray)
#   Downloading certifi-2024.12.14-py3-none-any.whl.metadata (2.3 kB)
# Collecting wrapt (from smart-open->ray[default])
#   Downloading wrapt-1.17.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.3 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading google_auth-2.37.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=2.0.0->torchmetrics)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=11.2.0->memray->ray[default])
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting pygments<3.0.0,>=2.13.0 (from rich>=11.2.0->memray->ray[default])
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=11.2.0->memray->ray[default])
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting linkify-it-py<3,>=1 (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting mdit-py-plugins (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting uc-micro-py (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 4.0 MB/s eta 0:00:00
# ...
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting mdit-py-plugins (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting uc-micro-py (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default])
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default])
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 2.8 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.0.post0-py3-none-any.whl (819 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 15.6 MB/s eta 0:00:00
# Downloading torchvision-0.20.1-cp312-cp312-manylinux1_x86_64.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 22.5 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp312-cp312-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 7.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 33.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 81.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 20.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 16.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 13.0 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 14.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 31.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 19.6 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 38.3 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 9.7 MB/s eta 0:00:00
# Downloading ray-2.40.0-cp312-cp312-manylinux2014_x86_64.whl (67.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 19.9 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 25.2 MB/s eta 0:00:00
# Downloading numpy-2.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 24.7 MB/s eta 0:00:00
# Downloading aiohttp-3.11.11-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 91.0 MB/s eta 0:00:00
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 20.7 MB/s eta 0:00:00
# Downloading frozenlist-1.5.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (283 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.6/283.6 kB 45.7 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 32.8 MB/s eta 0:00:00
# Downloading grpcio-1.69.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 12.8 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading msgpack-1.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.4/401.4 kB 56.5 MB/s eta 0:00:00
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 17.4 MB/s eta 0:00:00
# Downloading pillow-11.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 30.8 MB/s eta 0:00:00
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 14.3 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 49.1 MB/s eta 0:00:00
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 92.4 MB/s eta 0:00:00
# Downloading pyarrow-18.1.0-cp312-cp312-manylinux_2_28_x86_64.whl (40.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 21.8 MB/s eta 0:00:00
# Downloading pydantic-2.10.5-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 57.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.27.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 89.7 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 39.8 MB/s eta 0:00:00
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 64.2 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 71.2 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 21.0 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 15.7 MB/s eta 0:00:00
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 52.5 MB/s eta 0:00:00
# Downloading virtualenv-20.28.1-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 29.5 MB/s eta 0:00:00
# Downloading filelock-3.16.1-py3-none-any.whl (16 kB)
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 36.5 MB/s eta 0:00:00
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.5/88.5 kB 17.9 MB/s eta 0:00:00
# Downloading memray-1.15.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 29.6 MB/s eta 0:00:00
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 25.9 MB/s eta 0:00:00
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 16.4 MB/s eta 0:00:00
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 15.8 MB/s eta 0:00:00
# Downloading aiohappyeyeballs-2.4.4-py3-none-any.whl (14 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-24.3.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 15.7 MB/s eta 0:00:00
# Downloading certifi-2024.12.14-py3-none-any.whl (164 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.9/164.9 kB 31.2 MB/s eta 0:00:00
# Downloading charset_normalizer-3.4.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (145 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.3/145.3 kB 27.5 MB/s eta 0:00:00
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 61.4 MB/s eta 0:00:00
# Downloading google_api_core-2.24.0-py3-none-any.whl (158 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.6/158.6 kB 30.9 MB/s eta 0:00:00
# Downloading idna-3.10-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.4/70.4 kB 14.5 MB/s eta 0:00:00
# Downloading jinja2-3.1.5-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.6/134.6 kB 25.9 MB/s eta 0:00:00
# Downloading jsonschema_specifications-2024.10.1-py3-none-any.whl (18 kB)
# Downloading multidict-6.1.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.0/131.0 kB 27.9 MB/s eta 0:00:00
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading platformdirs-4.3.6-py3-none-any.whl (18 kB)
# Downloading propcache-0.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.6/243.6 kB 42.3 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 42.5 MB/s eta 0:00:00
# Downloading rpds_py-0.22.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (385 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 385.7/385.7 kB 56.2 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading textual-1.0.0-py3-none-any.whl (660 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 71.0 MB/s eta 0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.4/128.4 kB 26.1 MB/s eta 0:00:00
# Downloading yarl-1.18.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.9/336.9 kB 53.4 MB/s eta 0:00:00
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 88.5 MB/s eta 0:00:00
# Downloading setuptools-75.8.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.3 MB/s eta 0:00:00
# Downloading wrapt-1.17.1-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 kB 19.0 MB/s eta 0:00:00
# Downloading google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 kB 37.2 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.66.0-py2.py3-none-any.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.7/221.7 kB 40.2 MB/s eta 0:00:00
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 17.9 MB/s eta 0:00:00
# Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 66.7 MB/s eta 0:00:00
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 12.8 MB/s eta 0:00:00
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 81.2 MB/s eta 0:00:00
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 34.0 MB/s eta 0:00:00
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 14.5 MB/s eta 0:00:00
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 17.0 MB/s eta 0:00:00
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: pytz, py-spy, opencensus-context, mpmath, distlib, colorful, wrapt, urllib3, uc-micro-py, tzdata, typing-extensions, tqdm, sympy, six, setuptools, rpds-py, PyYAML, pygments, pyasn1, pyarrow, protobuf, propcache, prometheus-client, platformdirs, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, multidict, msgpack, mdurl, MarkupSafe, idna, grpcio, fsspec, frozenlist, filelock, click, charset-normalizer, certifi, cachetools, attrs, annotated-types, aiohappyeyeballs, yarl, virtualenv, triton, tensorboardX, smart-open, rsa, requests, referencing, python-dateutil, pydantic-core, pyasn1-modules, proto-plus, nvidia-cusparse-cu12, nvidia-cudnn-cu12, markdown-it-py, linkify-it-py, lightning-utilities, jinja2, googleapis-common-protos, aiosignal, rich, pydantic, pandas, nvidia-cusolver-cu12, mdit-py-plugins, jsonschema-specifications, google-auth, aiohttp, torch, jsonschema, google-api-core, aiohttp-cors, torchvision, torchmetrics, textual, ray, opencensus, pytorch_lightning, memray
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 aiohappyeyeballs-2.4.4 aiohttp-3.11.11 aiohttp-cors-0.7.0 aiosignal-1.3.2 annotated-types-0.7.0 attrs-24.3.0 cachetools-5.5.0 certifi-2024.12.14 charset-normalizer-3.4.1 click-8.1.8 colorful-0.5.6 distlib-0.3.9 filelock-3.16.1 frozenlist-1.5.0 fsspec-2024.12.0 google-api-core-2.24.0 google-auth-2.37.0 googleapis-common-protos-1.66.0 grpcio-1.69.0 idna-3.10 jinja2-3.1.5 jsonschema-4.23.0 jsonschema-specifications-2024.10.1 lightning-utilities-0.11.9 linkify-it-py-2.0.3 markdown-it-py-3.0.0 mdit-py-plugins-0.4.2 mdurl-0.1.2 memray-1.15.0 mpmath-1.3.0 msgpack-1.1.0 multidict-6.1.0 networkx-3.4.2 numpy-2.2.1 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 opencensus-0.11.4 opencensus-context-0.1.3 packaging-24.2 pandas-2.2.3 pillow-11.1.0 platformdirs-4.3.6 prometheus-client-0.21.1 propcache-0.2.1 proto-plus-1.25.0 protobuf-5.29.3 py-spy-0.4.0 pyarrow-18.1.0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.10.5 pydantic-core-2.27.2 pygments-2.19.1 python-dateutil-2.9.0.post0 pytorch_lightning-2.5.0.post0 pytz-2024.2 ray-2.40.0 referencing-0.35.1 requests-2.32.3 rich-13.9.4 rpds-py-0.22.3 rsa-4.9 setuptools-75.8.0 six-1.17.0 smart-open-7.1.0 sympy-1.13.1 tensorboardX-2.6.2.2 textual-1.0.0 torch-2.5.1 torchmetrics-1.6.1 torchvision-0.20.1 tqdm-4.67.1 triton-3.1.0 typing-extensions-4.12.2 tzdata-2024.2 uc-micro-py-1.0.3 urllib3-2.3.0 virtualenv-20.28.1 wrapt-1.17.1 yarl-1.18.3

# %%
# Let's run a broken command to stop execution here
PAUSE-EXECUTION-print(f'Broken print command to stop execution here')
#input("Execution paused. Hit Enter after running ray add and python ml example manually")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Let's run a broken command to stop execution here
# ----> 2 duhprint(f'Broken print command to stop execution here')
#       3 #input("Execution paused. Hit Enter after running ray add and python ml example manually")
#
# NameError: name 'duhprint' is not defined

# %%
node1.download_file('./cern-ray-microbm-node1.txt', 'cern-ray-microbm-node1.txt')
node2.download_file('./cern-ray-microbm-node2.txt', 'cern-ray-microbm-node2.txt')

# %%
#scp -F ~/.ssh/fabric_ssh_config -i <private *sliver* key file>  ubuntu@11.22.33.44:~/<remote file name> <local file name>
node.download_directory('/tmp/ray/session_latest', '.')

# %% [markdown]
# We now compile the `.cu` file using `nvcc`, the CUDA compiler tool installed with CUDA. In this example, we create an executable called `hello_world`.

# %%
stdout, stderr = node1.execute(f"/usr/local/cuda-{12.6}/bin/nvcc -o hello_world hello-world.cu")
stdout, stderr = node2.execute(f"/usr/local/cuda-{12.6}/bin/nvcc -o hello_world hello-world.cu")

# %% [markdown]
# Finally, run the executable:

# %%
stdout, stderr = node1.execute("./hello_world")
print(f"stdout: {stdout}")

stdout, stderr = node2.execute("./hello_world")
print(f"stdout: {stdout}")
# Out:
# Hello World!
# stdout: Hello World!
#
# Hello World!
# stdout: Hello World!

# %%
stdout, stderr = node1.execute("bash ./installer.sh")
stdout, stderr = node1.execute("python3 ./lightning_mnist_example.py")
# Out:
# Reading package lists...
# Building dependency tree...
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#
# Reading state information...
# ubuntu-drivers-common is already the newest version (1:0.9.7.6ubuntu3.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
#  udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   ERROR:root:aplay command not found
#  == /sys/devices/pci0000:00/0000:00:02.6/0000:08:00.0 ==
# modalias : pci:v000010DEd00002235sv000010DEsd0000145Abc03sc02i00
# vendor   : NVIDIA Corporation
# model    : GA102GL [A40]
# driver   : nvidia-driver-560 - third-party non-free
# driver   : nvidia-driver-535 - distro non-free
# driver   : nvidia-driver-470 - distro non-free
# driver   : nvidia-driver-555 - third-party non-free
# driver   : nvidia-driver-555-open - third-party non-free
# driver   : nvidia-driver-565-open - third-party non-free
# driver   : nvidia-driver-560-open - third-party non-free
# driver   : nvidia-driver-535-open - distro non-free
# driver   : nvidia-driver-565 - third-party non-free recommended
# driver   : nvidia-driver-535-server - distro non-free
# driver   : nvidia-driver-470-server - distro non-free
# driver   : nvidia-driver-535-server-open - distro non-free
# driver   : nvidia-driver-550 - third-party non-free
# driver   : nvidia-driver-550-open - third-party non-free
# driver   : xserver-xorg-video-nouveau - distro free builtin
#
#  udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
# udevadm hwdb is deprecated. Use systemd-hwdb instead.
#   ERROR:root:aplay command not found
#  All the available drivers are already installed.
#
#   WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-full is already the newest version (3.12.3-0ubuntu2).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3.12-venv is already the newest version (3.12.3-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
#
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
#  Reading package lists...
# Building dependency tree...
# Reading state information...
# python3-pip is already the newest version (24.0+dfsg-1ubuntu1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.
# pip 24.0 from /usr/lib/python3/dist-packages/pip (python 3.12)
# Requirement already satisfied: torchmetrics in ./ray-venv/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: pytorch_lightning in ./ray-venv/lib/python3.12/site-packages (2.5.0.post0)
# Requirement already satisfied: torchvision in ./ray-venv/lib/python3.12/site-packages (0.20.1)
# Requirement already satisfied: ray in ./ray-venv/lib/python3.12/site-packages (2.40.0)
# Requirement already satisfied: pandas in ./ray-venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy in ./ray-venv/lib/python3.12/site-packages (2.2.1)
# Requirement already satisfied: packaging>17.1 in ./ray-venv/lib/python3.12/site-packages (from torchmetrics) (24.2)
# Requirement already satisfied: torch>=2.0.0 in ./ray-venv/lib/python3.12/site-packages (from torchmetrics) (2.5.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in ./ray-venv/lib/python3.12/site-packages (from torchmetrics) (0.11.9)
# Requirement already satisfied: tqdm>=4.57.0 in ./ray-venv/lib/python3.12/site-packages (from pytorch_lightning) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in ./ray-venv/lib/python3.12/site-packages (from pytorch_lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in ./ray-venv/lib/python3.12/site-packages (from fsspec[http]>=2022.5.0->pytorch_lightning) (2024.12.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in ./ray-venv/lib/python3.12/site-packages (from pytorch_lightning) (4.12.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./ray-venv/lib/python3.12/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: filelock in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.16.1)
# Requirement already satisfied: networkx in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.4.2)
# Requirement already satisfied: jinja2 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (3.1.0)
# Requirement already satisfied: setuptools in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in ./ray-venv/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./ray-venv/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: click>=7.0 in ./ray-venv/lib/python3.12/site-packages (from ray) (8.1.8)
# Requirement already satisfied: jsonschema in ./ray-venv/lib/python3.12/site-packages (from ray) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./ray-venv/lib/python3.12/site-packages (from ray) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in ./ray-venv/lib/python3.12/site-packages (from ray) (5.29.3)
# Requirement already satisfied: aiosignal in ./ray-venv/lib/python3.12/site-packages (from ray) (1.3.2)
# Requirement already satisfied: frozenlist in ./ray-venv/lib/python3.12/site-packages (from ray) (1.5.0)
# Requirement already satisfied: requests in ./ray-venv/lib/python3.12/site-packages (from ray) (2.32.3)
# Requirement already satisfied: aiohttp>=3.7 in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (3.11.11)
# Requirement already satisfied: aiohttp-cors in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (0.7.0)
# Requirement already satisfied: colorful in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (0.4.0)
# Requirement already satisfied: opencensus in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (2.10.5)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (0.21.1)
# Requirement already satisfied: smart-open in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (20.28.1)
# Requirement already satisfied: grpcio>=1.42.0 in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (1.69.0)
# Requirement already satisfied: memray in ./ray-venv/lib/python3.12/site-packages (from ray[default]) (1.15.0)
# Requirement already satisfied: tensorboardX>=1.9 in ./ray-venv/lib/python3.12/site-packages (from ray[train]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in ./ray-venv/lib/python3.12/site-packages (from ray[train]) (18.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./ray-venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./ray-venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./ray-venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./ray-venv/lib/python3.12/site-packages (from aiohttp>=3.7->ray[default]) (2.4.4)
# Requirement already satisfied: attrs>=17.3.0 in ./ray-venv/lib/python3.12/site-packages (from aiohttp>=3.7->ray[default]) (24.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./ray-venv/lib/python3.12/site-packages (from aiohttp>=3.7->ray[default]) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in ./ray-venv/lib/python3.12/site-packages (from aiohttp>=3.7->ray[default]) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./ray-venv/lib/python3.12/site-packages (from aiohttp>=3.7->ray[default]) (1.18.3)
# Requirement already satisfied: annotated-types>=0.6.0 in ./ray-venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in ./ray-venv/lib/python3.12/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default]) (2.27.2)
# Requirement already satisfied: six>=1.5 in ./ray-venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in ./ray-venv/lib/python3.12/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]) (0.3.9)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in ./ray-venv/lib/python3.12/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default]) (4.3.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./ray-venv/lib/python3.12/site-packages (from jsonschema->ray) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in ./ray-venv/lib/python3.12/site-packages (from jsonschema->ray) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./ray-venv/lib/python3.12/site-packages (from jsonschema->ray) (0.22.3)
# Requirement already satisfied: rich>=11.2.0 in ./ray-venv/lib/python3.12/site-packages (from memray->ray[default]) (13.9.4)
# Requirement already satisfied: textual>=0.41.0 in ./ray-venv/lib/python3.12/site-packages (from memray->ray[default]) (1.0.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in ./ray-venv/lib/python3.12/site-packages (from opencensus->ray[default]) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./ray-venv/lib/python3.12/site-packages (from opencensus->ray[default]) (2.24.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./ray-venv/lib/python3.12/site-packages (from requests->ray) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./ray-venv/lib/python3.12/site-packages (from requests->ray) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./ray-venv/lib/python3.12/site-packages (from requests->ray) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./ray-venv/lib/python3.12/site-packages (from requests->ray) (2024.12.14)
# Requirement already satisfied: wrapt in ./ray-venv/lib/python3.12/site-packages (from smart-open->ray[default]) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./ray-venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.66.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./ray-venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.25.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in ./ray-venv/lib/python3.12/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (2.37.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./ray-venv/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./ray-venv/lib/python3.12/site-packages (from rich>=11.2.0->memray->ray[default]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./ray-venv/lib/python3.12/site-packages (from rich>=11.2.0->memray->ray[default]) (2.19.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./ray-venv/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./ray-venv/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./ray-venv/lib/python3.12/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.9)
# Requirement already satisfied: mdurl~=0.1 in ./ray-venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.2.0->memray->ray[default]) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in ./ray-venv/lib/python3.12/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default]) (2.0.3)
# Requirement already satisfied: mdit-py-plugins in ./ray-venv/lib/python3.12/site-packages (from markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default]) (0.4.2)
# Requirement already satisfied: uc-micro-py in ./ray-venv/lib/python3.12/site-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]>=2.1.0->textual>=0.41.0->memray->ray[default]) (1.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./ray-venv/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.6.1)
#  Traceback (most recent call last):
#   File "/home/ubuntu/./lightning_mnist_example.py", line 40, in <module>
#     import numpy as np
# ModuleNotFoundError: No module named 'numpy'

# %%
#do this instead of above cell -- run example in a bash script
node1.upload_file('./lightning_mnist_example_cpu1gpu1_installer.sh', 'lightning_mnist_example_cpu1gpu1_installer.sh')
stdout, stderr = node1.execute("bash ./lightning_mnist_example_cpu1gpu1_installer.sh")
print(f"stdout: {stdout}")

# %%
# now add a 2nd ray node to the cluster and run again on head node
# ray add???
stdout, stderr = node1.execute("bash ./installer.sh")
stdout, stderr = node1.execute("python3 ./lightning_mnist_example.py")

# %% [markdown]
# If you see `Hello World!`, the CUDA program ran successfully. `World!` was computed on the GPU from an array of offsets being summed with the string `Hello `, and the resut was printed to stdout.
#
# ### Congratulations! You have now successfully run a program on a FABRIC GPU!

# %% [markdown]
# ## Cleanup Your Experiment

# %%
fablib.delete_slice(slice_name)

# %%
#extend slice
from datetime import datetime
from datetime import timezone
from datetime import timedelta

#Set end host to now plus 14 days
end_date = (datetime.now(timezone.utc) + timedelta(days=14)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice = fablib.get_slice(name=slice_name)

    slice.renew(end_date)
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Retry: 0, Time: 23 sec
# <style type="text/css">
# #T_910a4 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_910a4 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_910a4 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_910a4_row0_col0, #T_910a4_row0_col1, #T_910a4_row1_col0, #T_910a4_row1_col1, #T_910a4_row2_col0, #T_910a4_row2_col1, #T_910a4_row3_col0, #T_910a4_row3_col1, #T_910a4_row4_col0, #T_910a4_row4_col1, #T_910a4_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_910a4_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_910a4">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_910a4_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_910a4_row0_col1" class="data row0 col1" >c02bacf6-d049-4522-8878-8446d8a6a33c</td>
#     </tr>
#     <tr>
#       <td id="T_910a4_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_910a4_row1_col1" class="data row1 col1" >A40-CERN-perf1</td>
#     </tr>
#     <tr>
#       <td id="T_910a4_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_910a4_row2_col1" class="data row2 col1" >2025-01-26 18:20:51 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_910a4_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_910a4_row3_col1" class="data row3 col1" >2025-01-13 14:47:08 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_910a4_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_910a4_row4_col1" class="data row4 col1" >1eb0c915-27b6-4421-aab1-27ae42ded922</td>
#     </tr>
#     <tr>
#       <td id="T_910a4_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_910a4_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_d5c75 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_d5c75 th {
#   text-align: left;
# }
# #T_d5c75 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d5c75 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d5c75 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d5c75_row0_col0, #T_d5c75_row0_col1, #T_d5c75_row0_col2, #T_d5c75_row0_col3, #T_d5c75_row0_col4, #T_d5c75_row0_col5, #T_d5c75_row0_col6, #T_d5c75_row0_col7, #T_d5c75_row0_col8, #T_d5c75_row0_col9, #T_d5c75_row0_col10, #T_d5c75_row0_col13, #T_d5c75_row0_col14, #T_d5c75_row0_col15, #T_d5c75_row1_col0, #T_d5c75_row1_col1, #T_d5c75_row1_col2, #T_d5c75_row1_col3, #T_d5c75_row1_col4, #T_d5c75_row1_col5, #T_d5c75_row1_col6, #T_d5c75_row1_col7, #T_d5c75_row1_col8, #T_d5c75_row1_col9, #T_d5c75_row1_col10, #T_d5c75_row1_col13, #T_d5c75_row1_col14, #T_d5c75_row1_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_d5c75_row0_col11, #T_d5c75_row1_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_d5c75_row0_col12, #T_d5c75_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_d5c75">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_d5c75_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_d5c75_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_d5c75_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_d5c75_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_d5c75_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_d5c75_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_d5c75_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_d5c75_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_d5c75_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_d5c75_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_d5c75_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_d5c75_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_d5c75_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_d5c75_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_d5c75_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_d5c75_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5c75_row0_col0" class="data row0 col0" >7cb0d975-8926-499f-8742-afc4684e4525</td>
#       <td id="T_d5c75_row0_col1" class="data row0 col1" >gpu-node1</td>
#       <td id="T_d5c75_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_d5c75_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_d5c75_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_d5c75_row0_col5" class="data row0 col5" >default_ubuntu_24</td>
#       <td id="T_d5c75_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_d5c75_row0_col7" class="data row0 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_d5c75_row0_col8" class="data row0 col8" >CERN</td>
#       <td id="T_d5c75_row0_col9" class="data row0 col9" >ubuntu</td>
#       <td id="T_d5c75_row0_col10" class="data row0 col10" >2001:400:a100:3090:f816:3eff:fe43:6d39</td>
#       <td id="T_d5c75_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_d5c75_row0_col12" class="data row0 col12" ></td>
#       <td id="T_d5c75_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fe43:6d39</td>
#       <td id="T_d5c75_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_d5c75_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_d5c75_row1_col0" class="data row1 col0" >04751694-9c7f-4688-9a29-22c551a24435</td>
#       <td id="T_d5c75_row1_col1" class="data row1 col1" >gpu-node2</td>
#       <td id="T_d5c75_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_d5c75_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_d5c75_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_d5c75_row1_col5" class="data row1 col5" >default_ubuntu_24</td>
#       <td id="T_d5c75_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_d5c75_row1_col7" class="data row1 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_d5c75_row1_col8" class="data row1 col8" >CERN</td>
#       <td id="T_d5c75_row1_col9" class="data row1 col9" >ubuntu</td>
#       <td id="T_d5c75_row1_col10" class="data row1 col10" >2001:400:a100:3090:f816:3eff:fea7:bb66</td>
#       <td id="T_d5c75_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_d5c75_row1_col12" class="data row1 col12" ></td>
#       <td id="T_d5c75_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2001:400:a100:3090:f816:3eff:fea7:bb66</td>
#       <td id="T_d5c75_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_d5c75_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_32fe6 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_32fe6 th {
#   text-align: left;
# }
# #T_32fe6 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_32fe6 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_32fe6 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_32fe6_row0_col0, #T_32fe6_row0_col1, #T_32fe6_row0_col2, #T_32fe6_row0_col3, #T_32fe6_row0_col4, #T_32fe6_row0_col5, #T_32fe6_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_32fe6_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_32fe6_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_32fe6">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_32fe6_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_32fe6_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_32fe6_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_32fe6_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_32fe6_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_32fe6_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_32fe6_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_32fe6_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_32fe6_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_32fe6_row0_col0" class="data row0 col0" >241c2623-305c-4238-86d0-59a5c2b238e5</td>
#       <td id="T_32fe6_row0_col1" class="data row0 col1" >net1</td>
#       <td id="T_32fe6_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_32fe6_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_32fe6_row0_col4" class="data row0 col4" >CERN</td>
#       <td id="T_32fe6_row0_col5" class="data row0 col5" >192.168.100.0/24</td>
#       <td id="T_32fe6_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_32fe6_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_32fe6_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_aef87 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_aef87 th {
#   text-align: left;
# }
# #T_aef87 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_aef87 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_aef87 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_aef87_row0_col0, #T_aef87_row0_col1, #T_aef87_row0_col2, #T_aef87_row0_col3, #T_aef87_row0_col4, #T_aef87_row0_col5, #T_aef87_row0_col6, #T_aef87_row0_col7, #T_aef87_row0_col8, #T_aef87_row0_col9, #T_aef87_row0_col10, #T_aef87_row0_col11, #T_aef87_row0_col12, #T_aef87_row1_col0, #T_aef87_row1_col1, #T_aef87_row1_col2, #T_aef87_row1_col3, #T_aef87_row1_col4, #T_aef87_row1_col5, #T_aef87_row1_col6, #T_aef87_row1_col7, #T_aef87_row1_col8, #T_aef87_row1_col9, #T_aef87_row1_col10, #T_aef87_row1_col11, #T_aef87_row1_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_aef87">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_aef87_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_aef87_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_aef87_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_aef87_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_aef87_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_aef87_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_aef87_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_aef87_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_aef87_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_aef87_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_aef87_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_aef87_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#       <th id="T_aef87_level0_col12" class="col_heading level0 col12" >Switch Port</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_aef87_row0_col0" class="data row0 col0" >gpu-node1-nic1-p1</td>
#       <td id="T_aef87_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_aef87_row0_col2" class="data row0 col2" >gpu-node1</td>
#       <td id="T_aef87_row0_col3" class="data row0 col3" >net1</td>
#       <td id="T_aef87_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_aef87_row0_col5" class="data row0 col5" >auto</td>
#       <td id="T_aef87_row0_col6" class="data row0 col6" ></td>
#       <td id="T_aef87_row0_col7" class="data row0 col7" >02:1D:B9:31:E7:23</td>
#       <td id="T_aef87_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_aef87_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_aef87_row0_col10" class="data row0 col10" >192.168.100.2</td>
#       <td id="T_aef87_row0_col11" class="data row0 col11" >6</td>
#       <td id="T_aef87_row0_col12" class="data row0 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#     <tr>
#       <td id="T_aef87_row1_col0" class="data row1 col0" >gpu-node2-nic1-p1</td>
#       <td id="T_aef87_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_aef87_row1_col2" class="data row1 col2" >gpu-node2</td>
#       <td id="T_aef87_row1_col3" class="data row1 col3" >net1</td>
#       <td id="T_aef87_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_aef87_row1_col5" class="data row1 col5" >auto</td>
#       <td id="T_aef87_row1_col6" class="data row1 col6" ></td>
#       <td id="T_aef87_row1_col7" class="data row1 col7" >02:B5:53:89:2C:E6</td>
#       <td id="T_aef87_row1_col8" class="data row1 col8" >enp8s0</td>
#       <td id="T_aef87_row1_col9" class="data row1 col9" >enp8s0</td>
#       <td id="T_aef87_row1_col10" class="data row1 col10" >192.168.100.1</td>
#       <td id="T_aef87_row1_col11" class="data row1 col11" >6</td>
#       <td id="T_aef87_row1_col12" class="data row1 col12" >HundredGigE0/0/0/5</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 23 seconds
